# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
from scipy.stats import ks_2samp
import matplotlib.pyplot as plt

# %%
reverse_list = [0,1,2,3,4,5,6,7,8,11,15,16,18,19,
                22,24,25,26,27,41,29,
                32,35,37,40,48,49,47,
                55,51,52,53,60,61,62,103,65,66,67,69,
                70,71,74,78,79,
                82,84,89,90,91,94,95,96,97,99,
                105,106,110,111,112,118,119,125,128,
                130,133,134,135,137,138,
                140,144,145,147,151,155,157,159,
                161,162,163,164,167,168,
                170,171,173,175,176,179,
                180,181,184,185,187,189,
                190,191,195,196,199]

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def scale_dfs(train_df, test_df):
    public_index = np.load("../input/public_LB.npy")
    private_index = np.load("../input/private_LB.npy")
    synthetic_index = np.load("../input/synthetic_samples_indexes.npy")
    private_df, public_df, synthetic_df = test_df.iloc[private_index], test_df.iloc[public_index], test_df.iloc[synthetic_index]
    
    df = pd.concat([train_df, private_df, public_df])
    for col in df.columns:
        mean = df[col].mean()
        std = df[col].std()
        df[col] = (df[col] - mean)/std
        test_df[col] = (test_df[col] - mean)/std
    return df[:len(train_df)], test_df

# %% [raw]
# def scale_col(col):
#     min_val = col.min()
#     max_val = col.max()
#     return (col-min_val)/(max_val - min_val)

# %%
train_labels = train_df['target']
train_index = np.array(train_df.index)

train_df.drop(['ID_code', 'target'], axis=1, inplace=True)
test_df.drop(['ID_code'], axis=1, inplace=True)

# %%
train_df, test_df = scale_dfs(train_df, test_df)

# %% [raw]
# for col in train_df.columns[:5]:
#     plt.plot()
#     sns.distplot(train_df[col], label="Train", hist=False)
#     sns.distplot(test_df[col], label="Test", hist=False)
#     plt.legend()
#     plt.show()

# %%
df = pd.concat([train_df, test_df])
df.iloc[:,reverse_list] = df.iloc[:,reverse_list]*-1
train_df, test_df = df[:len(train_df)], df[len(train_df):]

# %%
train_df.head()
# Out:
#       var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# 0  0.575795  1.274444 -0.453379  0.830418 -0.236350  0.537107  0.336720
# 1 -0.271662  0.622371 -1.192676  0.685742 -0.792504 -1.539111 -0.242780
# 2  0.679856  0.276048 -0.518717 -0.538043  0.305429  0.511711 -1.768452
# 3 -0.126794  0.129301  0.666879 -0.197321 -0.929708 -0.409944 -0.499001
# 4  0.275856 -0.035855 -0.819674  0.075511 -0.740066 -0.954817 -0.611762
#
#       var_7     var_8     var_9    ...      var_190   var_191   var_192  \
# 0 -0.609621  1.561255 -1.474505    ...    -0.266249  1.150882  0.817744
# 1  0.002261 -0.859338  0.419448    ...    -0.969442 -0.091191  0.443836
# 2  0.563124  1.561045 -1.308042    ...     0.069197 -0.775204 -0.174022
# 3  0.472634  1.843590  0.548973    ...    -0.273091  0.893323 -0.818467
# 4 -0.792297 -1.795132  0.090005    ...     1.033234 -0.686243 -1.406086
#
#     var_193   var_194   var_195   var_196   var_197   var_198   var_199
# ...

# %% [raw]
# train_unique_count = np.zeros_like(train_df)
# for col in range(len(train_df.columns)):
#     _, index_, count_ = np.unique(train_df.values[:,col], return_counts=True, return_index=True)
#     train_unique_count[index_[count_ == 1], col] += 1
#
# train_df["unique_count_1"] = np.sum(train_unique_count, axis=1)

# %% [raw]
# test_unique_count = np.zeros_like(test_df)
# for col in range(len(test_df.columns)):
#     _, index_, count_ = np.unique(test_df.values[:,col], return_counts=True, return_index=True)
#     test_unique_count[index_[count_ == 1], col] += 1
#
# test_df["unique_count_1"] = np.sum(test_unique_count, axis=1)
# test_df = test_df[test_df["unique_count_1"] > 0]

# %% [raw]
# train_df["unique_count_1"], test_df["unique_count_1"] = scale_col(train_df["unique_count_1"]), scale_col(test_df["unique_count_1"])

# %% [raw]
# sns.distplot(train_df["unique_count_1"], label="Train", hist=False)
# sns.distplot(test_df["unique_count_1"], label="Test", hist=False)
# sns.distplot(train_df[train_labels==1]["unique_count_1"], label="Target=1", hist=False)
# sns.distplot(train_df[train_labels==0]["unique_count_1"], label="Target=0", hist=False)

# %% [raw]
# df = pd.concat([train_df, test_df])

# %% [raw]
# unique_count = np.zeros_like(df)
# for col in range(len(df.columns)):
#     _, index_, count_ = np.unique(df.values[:,col], return_counts=True, return_index=True)
#     unique_count[index_[count_ == 1], col] += 1

# %% [raw]
# train_df["unique_count_2"] = np.sum(unique_count, axis=1)[:len(train_df)]
# train_df["unique_count_2"] = scale_col(train_df["unique_count_2"])
# train_df["unique_count_diff"] = train_df["unique_count_1"] - train_df["unique_count_2"]
#
# test_df["unique_count_2"] = np.sum(unique_count, axis=1)[len(train_df):]
# test_df["unique_count_2"] = scale_col(test_df["unique_count_2"])
# test_df["unique_count_diff"] = test_df["unique_count_1"] - test_df["unique_count_2"]

# %% [raw]
# sns.distplot(train_df["unique_count_diff"], label="Train", hist=False)
# sns.distplot(test_df["unique_count_diff"], label="Test", hist=False)
# sns.distplot(train_df[train_labels==1]["unique_count_diff"], label="Target=1", hist=False)
# sns.distplot(train_df[train_labels==0]["unique_count_diff"], label="Target=0", hist=False)

# %% [raw]
# train_abs_mean = np.mean(np.abs(train_df.values),axis=1)
# test_abs_mean = np.mean(np.abs(test_df.values),axis=1)

# %% [raw]
# train_mean = np.mean(train_df.values, axis=1)
# test_mean = np.mean(test_df.values, axis=1)

# %% [raw]
# def fractional_part(train_df, test_df):
#     df = pd.concat([train_df, test_df])
#     col_list = ["var_1", "var_5", "var_11", "var_12", "var_13", "var_26", "var_32", "var_35",
#  "var_36", "var_40", "var_44", "var_45", "var_52", "var_58", "var_76", "var_80",
# "var_86","var_91","var_99","var_115","var_118", "var_123", "var_139", "var_147",
# "var_148", "var_149", "var_155", "var_164", "var_167", "var_180"]
#     for col in col_list:
#         df[col+"_frac_part"] = df[col].apply(lambda x: x-int(x))
#     return df[:len(train_df)], df[len(train_df):]

# %% [raw]
# train_df, test_df = fractional_part(train_df, test_df)

# %% [raw]
# train_df["mean_feats_with_frac"] = np.mean(train_df.values, axis=1)
# test_df["mean_feats_with_frac"] = np.mean(test_df.values, axis=1)

# %% [raw]
# train_df["mean_feats"] = train_mean
# test_df["mean_feats"] = test_mean

# %% [raw]
# train_df["abs_mean_feats"] = train_abs_mean
# test_df["abs_mean_feats"] = test_abs_mean

# %% [raw]
# train_df["abs_mean_feats_with_frac"] = np.mean(np.abs(train_df.values),axis=1)
# test_df["abs_mean_feats_with_frac"] = np.mean(np.abs(test_df.values),axis=1)

# %% [raw]
# ks_2samp(train_df[train_labels==0]["mean_feats"], train_df[train_labels==1]["mean_feats"])

# %% [raw]
# ks_2samp(train_df[train_labels==0]["mean_feats_with_frac"], train_df[train_labels==1]["mean_feats_with_frac"])

# %% [raw]
# def getp_vec_sum(x,x_sort,y,std,c=0.5):
#     # x is sorted
#     left = x - std/c
#     right = x + std/c
#     p_left = np.searchsorted(x_sort,left)
#     p_right = np.searchsorted(x_sort,right)
#     p_right[p_right>=y.shape[0]] = y.shape[0]-1
#     p_left[p_left>=y.shape[0]] = y.shape[0]-1
#     return (y[p_right]-y[p_left])

# %% [raw]
# def get_pdf(tr,col,x_query=None,smooth=3):
#     std = tr[col].std()
#     df = tr.groupby(col).agg({'target':['sum','count']})
#     cols = ['sum_y','count_y']
#     df.columns = cols
#     df = df.reset_index()
#     df = df.sort_values(col)
#     y,c = cols
#
#     df[y] = df[y].cumsum()
#     df[c] = df[c].cumsum()
#
#     if x_query is None:
#         rmin,rmax,res = -5.0, 5.0, 501
#         x_query = np.linspace(rmin,rmax,res)
#
#     dg = pd.DataFrame()
#     tm = getp_vec_sum(x_query,df[col].values,df[y].values,std,c=smooth)
#     cm = getp_vec_sum(x_query,df[col].values,df[c].values,std,c=smooth)+1
#     dg['res'] = tm/cm
#     dg.loc[cm<500,'res'] = 0.1
#     return dg['res'].values

# %% [raw]
# def get_pdfs(tr):
#     y = []
#     for i in tr.columns:
#         if i != "target":
#             res = get_pdf(tr,i)
#             y.append(res)
#     return np.vstack(y)

# %% [raw]
# def print_corr(corr_mat,col,bar=0.97):
#     cols = corr_mat.loc[corr_mat[col]>bar,col].index.values
#     return cols

# %% [raw]
# tr = pd.concat([train_df, train_labels],axis=1)

# %% [raw]
# prob = get_pdf(tr,'var_1_frac_part')
# plt.plot(prob)

# %% [raw]
# %%time
# pdfs = get_pdfs(tr)

# %% [raw]
# %%time
# df_pdf = pd.DataFrame(pdfs.T,columns=train_df.columns)
# corr_mat = df_pdf.corr(method='pearson')

# %% [raw]
# corr_mat.head()

# %% [raw]
# print_corr(corr_mat,"var_1_frac_part")

# %% [raw]
# %%time
# groups = []
# skip_list = set()
# for col in train_df.columns:
#     if col not in skip_list:
#         cols = print_corr(corr_mat,col)
#         if len(cols)>1:
#             groups.append(cols)
#             for v in cols:
#                 skip_list.add(v)
# print(len(groups))

# %% [raw]
# groups

# %% [raw]
# for i, cols in enumerate(groups):
#     train_df["mean_groupfeats_{}".format(i)] = np.mean(train_df[cols].values, axis=1)
#     test_df["mean_groupfeats_{}".format(i)] = np.mean(test_df[cols].values, axis=1)

# %% [raw]
# for col in train_df.columns[200:]:
#     print("{}: {}".format(col, ks_2samp(train_df[train_labels==0][col], train_df[train_labels==1][col])))

# %% [raw]
# statistics_dict = {}
# for col in train_df.columns:
#     statistic, pvalue = ks_2samp(train_df[train_labels==0][col], train_df[train_labels==1][col])
#     statistics_dict[col] = statistic
#     #fig, ax = plt.subplots(1, 1, figsize=(10, 4))
#     #sns.kdeplot(train_df[train_labels==0][col], ax=ax, label='Target == 0')
#     #sns.kdeplot(train_df[train_labels==1][col], ax=ax, label='Target == 1')
#     #ax.set_title('name: {}, statistics: {:.5f}, pvalue: {:5f}'.format(col, statistic, pvalue))
#     #plt.show()

# %% [raw]
# sorted(statistics_dict.items(), reverse=True, key=lambda x: x[1])

# %%
df.head()
# Out:
#       var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# 0  0.575795  1.274444 -0.453379  0.830418 -0.236350  0.537107  0.336720
# 1 -0.271662  0.622371 -1.192676  0.685742 -0.792504 -1.539111 -0.242780
# 2  0.679856  0.276048 -0.518717 -0.538043  0.305429  0.511711 -1.768452
# 3 -0.126794  0.129301  0.666879 -0.197321 -0.929708 -0.409944 -0.499001
# 4  0.275856 -0.035855 -0.819674  0.075511 -0.740066 -0.954817 -0.611762
#
#       var_7     var_8     var_9    ...      var_190   var_191   var_192  \
# 0 -0.609621  1.561255 -1.474505    ...    -0.266249  1.150882  0.817744
# 1  0.002261 -0.859338  0.419448    ...    -0.969442 -0.091191  0.443836
# 2  0.563124  1.561045 -1.308042    ...     0.069197 -0.775204 -0.174022
# 3  0.472634  1.843590  0.548973    ...    -0.273091  0.893323 -0.818467
# 4 -0.792297 -1.795132  0.090005    ...     1.033234 -0.686243 -1.406086
#
#     var_193   var_194   var_195   var_196   var_197   var_198   var_199
# ...

# %%
for i, col in enumerate(df.columns[:200]):
    if col != "var_68":
        temp = df.groupby("var_68", as_index=False).agg({col:{"max_{}".format(col):np.max, 
                                                                    "min_{}".format(col):np.min}})
        temp.columns = ["var_68", "max_{}".format(col), "min_{}".format(col)]
        temp["maxmin_diff_{}".format(i)] = temp["max_{}".format(col)]-temp["min_{}".format(col)]
        temp.drop(columns=["max_{}".format(col), "min_{}".format(col)], inplace=True)

        df = pd.merge(df, temp, how="left", on="var_68")

# %%
df.head()
# Out:
#       var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# 0  0.575795  1.274444 -0.453379  0.830418 -0.236350  0.537107  0.336720
# 1 -0.271662  0.622371 -1.192676  0.685742 -0.792504 -1.539111 -0.242780
# 2  0.679856  0.276048 -0.518717 -0.538043  0.305429  0.511711 -1.768452
# 3 -0.126794  0.129301  0.666879 -0.197321 -0.929708 -0.409944 -0.499001
# 4  0.275856 -0.035855 -0.819674  0.075511 -0.740066 -0.954817 -0.611762
#
#       var_7     var_8     var_9       ...         maxmin_diff_196  \
# 0 -0.609621  1.561255 -1.474505       ...                5.054581
# 1  0.002261 -0.859338  0.419448       ...                4.735194
# 2  0.563124  1.561045 -1.308042       ...                5.255114
# 3  0.472634  1.843590  0.548973       ...                4.735194
# 4 -0.792297 -1.795132  0.090005       ...                5.038681
#
#    max_var_197  min_var_197  maxmin_diff_197  max_var_198  min_var_198  \
# ...

# %%
train_df, test_df = df[:len(train_df)], df[len(train_df):]

# %%
statistics_dict = {}
for col in train_df.columns[200:]:
    statistic, pvalue = ks_2samp(train_df[train_labels==0][col], train_df[train_labels==1][col])
    statistics_dict[col] = statistic
    #fig, ax = plt.subplots(1, 1, figsize=(10, 4))
    #sns.kdeplot(train_df[train_labels==0][col], ax=ax, label='Target == 0')
    #sns.kdeplot(train_df[train_labels==1][col], ax=ax, label='Target == 1')
    #ax.set_title('name: {}, statistics: {:.5f}, pvalue: {:5f}'.format(col, statistic, pvalue))
    #plt.show()

# %%
sorted(statistics_dict.items(), reverse=True, key=lambda x: x[1])
# Out:
# [('maxmin_diff_188', 0.017845399865922984),
#  ('maxmin_diff_130', 0.01694960582352817),
#  ('min_var_78', 0.016945191704360207),
#  ('maxmin_diff_107', 0.016562184447522887),
#  ('min_var_41', 0.016548912220039624),
#  ('max_var_165', 0.01611539980648169),
#  ('max_var_188', 0.016085311333782326),
#  ('maxmin_diff_125', 0.01607542049858901),
#  ('min_var_43', 0.016052441080970647),
#  ('max_var_171', 0.015965038202558512),
#  ('maxmin_diff_54', 0.015925764158066846),
#  ('max_var_17', 0.01592251773383163),
#  ('maxmin_diff_16', 0.015917908353502486),
#  ('maxmin_diff_147', 0.01578452174820416),
#  ('maxmin_diff_78', 0.015678485534166453),
#  ('min_var_26', 0.015601081907909597),
#  ('maxmin_diff_18', 0.015540250035556591),
#  ('maxmin_diff_53', 0.015525422356557073),
#  ('maxmin_diff_113', 0.015501218269786121),
#  ('maxmin_diff_135', 0.015368052923593944),
#  ('max_var_130', 0.015351311906473875),
#  ('max_var_127', 0.015278876100298155),
#  ('min_var_59', 0.015261314765042),
# ...

# %%
df.columns
# Out:
# Index(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7',
#        'var_8', 'var_9',
#        ...
#        'maxmin_diff_196', 'max_var_197', 'min_var_197', 'maxmin_diff_197',
#        'max_var_198', 'min_var_198', 'maxmin_diff_198', 'max_var_199',
#        'min_var_199', 'maxmin_diff_199'],
#       dtype='object', length=797)

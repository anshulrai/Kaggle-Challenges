# %%
import gc
import re
import os
import pandas as pd
import numpy as np
import random
from sklearn import metrics
import string
import math
import operator
import time
from keras.preprocessing import text, sequence
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.utils.data
from gensim import utils
# Out:
# Using TensorFlow backend.

# %%
def set_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# GENERAL HYPERPARAMS
num_folds = 5
seed = 42

# HYPERPARAMS FOR TEXT PROCESSING
max_features = 120000
maxlen = 100

# HYPERPARAMS FOR NN
batch_size = 1024
epochs_fixed = 4
epochs_trainable = 1
embed_size = 300
early_stopping_patience = 2
hidden_size = 60

set_seed(seed)

# %%
PATH = "./input/"

puncts = {'\u200b', ',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√'}

def clean_text(x):
    x = str(x)
    table = str.maketrans({key: ' {punct} ' for key in puncts})
    return x.translate(table)

def clean_numbers(x):
    if bool(re.search(r'\d', x)):
        x = re.sub('[0-9]{5,}', '#####', x)
        x = re.sub('[0-9]{4}', '####', x)
        x = re.sub('[0-9]{3}', '###', x)
        x = re.sub('[0-9]{2}', '##', x)
    return x

mispell_dict = {
"tamilans" : "tamilians",
"feku" : "liar",
"quorans" : "people who use quora",
"qoura": "quora",
"xiomi" : "phone",
"ipill" : "contraception",
"aren't" : "are not",
"can't" : "cannot",
"couldn't" : "could not",
"didn't" : "did not",
"doesn't" : "does not",
"don't" : "do not",
"hadn't" : "had not",
"hasn't" : "has not",
"haven't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "i would",
"i'd" : "i had",
"i'll" : "i will",
"i'm" : "i am",
"isn't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "i have",
"let's" : "let us",
"mightn't" : "might not",
"mustn't" : "must not",
"shan't" : "shall not",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"shouldn't" : "should not",
"that's" : "that is",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"weren't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"won't" : "will not",
"wouldn't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"wasn't": "was not",
"we'll":" we will",
"didn't": "did not",
"tryin'":"trying"}

def _get_mispell(mispell_dict):
    mispell_re = re.compile('(%s)' % '|'.join(mispell_dict.keys()))
    return mispell_dict, mispell_re

def replace_typical_misspell(text):
    mispellings, mispellings_re = _get_mispell(mispell_dict)
    def replace(match):
        return mispellings[match.group(0)]
    return mispellings_re.sub(replace, text)

# %%
# %%time

train_df = pd.read_csv(PATH+'train.csv', usecols=['question_text', 'target'])
test_df = pd.read_csv(PATH+'test.csv', usecols = ['question_text'])

# 3RD PARTY CLEAN
#train_df["question_text"] = train_df["question_text"].apply(lambda x: x.lower())
#test_df["question_text"] = test_df["question_text"].apply(lambda x: x.lower())

train_df["question_text"] = train_df["question_text"].apply(lambda x: clean_text(x))
test_df["question_text"] = test_df["question_text"].apply(lambda x: clean_text(x))

train_df["question_text"] = train_df["question_text"].apply(lambda x: clean_numbers(x))
test_df["question_text"] = test_df["question_text"].apply(lambda x: clean_numbers(x))

train_df["question_text"] = train_df["question_text"].apply(lambda x: replace_typical_misspell(x))
test_df["question_text"] = test_df["question_text"].apply(lambda x: replace_typical_misspell(x))

# FOR CREATING PROCESSED DATA AND LABELS
train_sentences = train_df['question_text']
train_labels = train_df['target']
test_sentences = test_df['question_text']

del train_df, test_df

gc.collect()

# TOKENIZE TEXT
tokenizer = text.Tokenizer(num_words=max_features, oov_token='OOV', lower=False)
tokenizer.fit_on_texts(list(train_sentences) + list(test_sentences))

tokenized_train = tokenizer.texts_to_sequences(train_sentences)
X_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)

tokenized_test = tokenizer.texts_to_sequences(test_sentences)
X_test = sequence.pad_sequences(tokenized_test, maxlen=maxlen)

del tokenized_test, tokenized_train, train_sentences, test_sentences
gc.collect()

word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index)+1)
# Out:
# CPU times: user 1min 47s, sys: 573 ms, total: 1min 47s
# Wall time: 1min 47s

# %%
# LIST OF ALL EMBEDDINGS USED
embedding_list = [PATH+'embeddings/paragram_300_sl999/paragram_300_sl999.txt', 
PATH+'embeddings/wiki-news-300d-1M/wiki-news-300d-1M.vec',
PATH+'embeddings/glove.840B.300d/glove.840B.300d.txt']

# MEAN AND STD VALUES FOR EMBEDDINGS
emb_mean_dict = {'paragram_300_sl999':-0.005324783269315958,
            'wiki-news-300d-1M':-0.0033469984773546457,
            'glove.840B.300d':-0.005838498938828707,
            'GoogleNews-vectors-negative300':-0.0051106834}

emb_std_dict = {'paragram_300_sl999':0.4934646189212799,
            'wiki-news-300d-1M':0.10985549539327621,
            'glove.840B.300d':0.4878219664096832,
            'GoogleNews-vectors-negative300':0.18445626}

global_mean = np.mean([i for i in emb_mean_dict.values()])
global_std = np.mean([i for i in emb_std_dict.values()])
global_embedding = np.random.normal(global_mean, global_std, (nb_words, embed_size))
embedding_count = np.zeros((nb_words,1))

# %%
# %%time
for EMBEDDING_FILE in embedding_list:
    embedding_name = EMBEDDING_FILE.split('/')[3]
    for o in open(EMBEDDING_FILE, encoding="utf8", errors='ignore'):
        word, vec = o.split(' ', 1)
        if word not in word_index:
            continue
        i = word_index[word]
        if i >= nb_words:
            continue
        embedding_vector = np.asarray(vec.split(' '), dtype='float32')[:embed_size]
        if len(embedding_vector) == embed_size:
            if embedding_count[i] == 0:
                global_embedding[i] = embedding_vector
            else:
                global_embedding[i] = (embedding_count[i]*global_embedding[i] + embedding_vector)/(embedding_count[i] + 1)
            embedding_count[i] += 1
    del embedding_vector
    gc.collect()
# Out:
# CPU times: user 32.4 s, sys: 2.62 s, total: 35 s
# Wall time: 35 s

# %%
pd.Series(embedding_count.flatten()).value_counts().sort_index()/len(embedding_count) * 100
# Out:
# 0.0     7.446667
# 1.0     3.472500
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64

# %% [raw]
# # No to lower
# 0.0     7.446667
# 1.0     3.472500
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64
#
# 0.0     13.775833
# 1.0      1.074167
# 2.0      3.471667
# 3.0     10.931667
# 4.0      9.928333
# 5.0     18.512500
# 6.0     23.145000
# 7.0     13.899167
# 8.0      2.923333
# 9.0      1.560833
# 10.0     0.395000
# 11.0     0.191667
# 12.0     0.071667
# 13.0     0.050833
# 14.0     0.026667
# 15.0     0.013333
# 16.0     0.009167
# 17.0     0.009167
# 18.0     0.005000
# 19.0     0.001667
# 21.0     0.002500
# 22.0     0.000833
# dtype: float64
#
# # New spellings
# 3.0    61.1275
# 2.0    15.1950
# 0.0    14.5275
# 1.0     9.1500
#
# # Old spellings
# 3.0    61.1225
# 2.0    15.1925
# 0.0    14.5350
# 1.0     9.1500
# dtype: float64

# %%
word2vecpath = PATH + 'embeddings/GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'

# %%
unique_words = set()

# %%
# %%time
with utils.smart_open(word2vecpath) as fin:
    header = utils.to_unicode(fin.readline(), encoding='utf8')
    vocab_size, vector_size = (int(x) for x in header.split())
    binary_len = np.dtype(np.float32).itemsize * vector_size
    for _ in tqdm(range(vocab_size)):
        word = []
        while True:
            ch = fin.read(1)
            if ch == b' ':
                break
            if ch == b'':
                raise EOFError("unexpected end of input")
            if ch != b'\n':
                word.append(ch)
        word = utils.to_unicode(b''.join(word), encoding='utf8', errors='strict')
        weights = np.fromstring(fin.read(binary_len), dtype=np.float32).astype(np.float32)
        if word not in word_index:
            continue
        i = word_index[word]
        if i >= nb_words or embedding_count[i] > 0:
            continue
        unique_words.add((word,i))
        global_embedding[i] = weights
        embedding_count[i] += 1
# Out:
#   0%|          | 0/3000000 [00:00<?, ?it/s]/home/apg/all_dl/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   app.launch_new_instance()
# 100%|██████████| 3000000/3000000 [00:33<00:00, 90613.33it/s]
# CPU times: user 32.2 s, sys: 1.51 s, total: 33.7 s
# Wall time: 33.1 s

# %%
pd.Series(embedding_count.flatten()).value_counts().sort_index()/len(embedding_count) * 100
# Out:
# 0.0     7.184167
# 1.0     3.735000
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64

# %% [raw]
# # No to lower
# 0.0     7.184167
# 1.0     3.735000
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64
#
# 0.0     13.230833
# 1.0      1.619167
# 2.0      3.471667
# 3.0     10.931667
# 4.0      9.928333
# 5.0     18.512500
# 6.0     23.145000
# 7.0     13.899167
# 8.0      2.923333
# 9.0      1.560833
# 10.0     0.395000
# 11.0     0.191667
# 12.0     0.071667
# 13.0     0.050833
# 14.0     0.026667
# 15.0     0.013333
# 16.0     0.009167
# 17.0     0.009167
# 18.0     0.005000
# 19.0     0.001667
# 21.0     0.002500
# 22.0     0.000833
# dtype: float64
#
# 3.0    61.127500
# 2.0    15.195000
# 0.0    14.460833
# 1.0     9.216667
# dtype: float64
#
# # word2vec with old spellings
# 3.0    61.122500
# 2.0    15.192500
# 0.0    14.468333
# 1.0     9.216667
# dtype: float64

# %%
len(unique_words)
# Out:
# 315

# %%
sorted(unique_words, key=lambda tup: tup[1])
# Out:
# [('bhakts', 12849),
#  ('NICMAR', 13079),
#  ('Awdhesh', 15039),
#  ('Skripal', 16686),
#  ('Alshamsi', 17181),
#  ('BIPC', 17547),
#  ('IISERs', 20109),
#  ('Byju', 21234),
#  ('UPSE', 22209),
#  ('Kalpit', 23119),
#  ('EFLU', 25644),
#  ('Kovind', 26999),
#  ('Strzok', 27353),
#  ('Kattankulathur', 27857),
#  ('Kainerugaba', 28464),
#  ('Warmbier', 28831),
#  ('PESU', 29713),
#  ('RGIPT', 30995),
#  ('DSCE', 32526),
#  ('LHMC', 33946),
#  ('KGMU', 34097),
#  ('Gurmehar', 37441),
#  ('PRMO', 38584),
#  ('NIFTEM', 39386),
#  ('IPHO', 40070),
#  ('Jozwik', 42042),
#  ('Bregoli', 43445),
#  ('1crore', 45068),
#  ('Delloite', 46168),
#  ('Rupay', 47777),
#  ('Kejariwal', 48961),
#  ('Kahoot', 49659),
#  ('PIVX', 51176),
#  ('GTPL', 51465),
#  ('multibaggers', 51954),
#  ('JN0', 52726),
#  ('SJMSOM', 52989),
#  ('Mersal', 53257),
#  ('MNLU', 53935),
#  ('SGTB', 54938),
#  ('PSIT', 55481),
#  ('IGRUA', 56196),
#  ('Bijwasan', 56394),
#  ('Kolkey', 56666),
#  ('Awadesh', 57230),
#  ('Hampankatta', 57999),
#  ('Dwarikesh', 58225),
#  ('Netralaya', 59341),
#  ('OPTCL', 59489),
#  ('Meghmani', 59850),
#  ('subinspector', 61056),
#  ('Cihon', 61103),
#  ('FIEM', 61624),
#  ('TenX', 62637),
#  ('Landran', 62933),
#  ('MVSR', 63142),
#  ('NLIU', 63209),
#  ('Kulbushan', 63283),
#  ('SRFTI', 64077),
#  ('retainership', 65010),
#  ('STCG', 65428),
#  ('SMVDU', 65557),
#  ('Acads', 66002),
#  ('Appium', 66035),
#  ('Myeshia', 66735),
#  ('Doncic', 66802),
#  ('Regenesys', 66818),
#  ('secondyear', 66973),
#  ('Duranto', 67528),
#  ('Mueth', 67653),
#  ('Dundigal', 68486),
#  ('PMEGP', 68591),
#  ('Swaroopa', 68621),
#  ('Glucon', 69641),
#  ('Koparkhairane', 70766),
#  ('Dawki', 70865),
#  ('Contris', 70888),
#  ('Jeou', 71649),
#  ('Bakliwal', 71984),
#  ('Kolhan', 72823),
#  ('Shiradi', 72939),
#  ('Anudeep', 73060),
#  ('SILCHAR', 73438),
#  ('Arbind', 73633),
#  ('Peeya', 73851),
#  ('PGPEX', 74730),
#  ('nutraloaf', 74775),
#  ('Raazi', 75284),
#  ('Ayog', 75638),
#  ('Yedyurappa', 76260),
#  ('Pandeshwar', 76676),
#  ('DISEC', 76763),
#  ('VGSOM', 76777),
#  ('Pahadis', 76852),
#  ('QLED', 76942),
#  ('answersheets', 77101),
#  ('Janambhoomi', 77495),
#  ('CoEP', 78086),
#  ('Tawhidi', 78410),
#  ('Mudipu', 79046),
#  ('Gboard', 79047),
#  ('CENP', 79488),
#  ('Samundra', 79767),
#  ('NDTL', 79893),
#  ('relagation', 80156),
#  ('Shoaibi', 80346),
#  ('hosteller', 80356),
#  ('DDIT', 81303),
#  ('Mehtani', 81328),
#  ('KRIBHCO', 81342),
#  ('IMTMA', 81736),
#  ('Gwader', 82071),
#  ('NITR', 82118),
#  ('JNMC', 82307),
#  ('Gossert', 82570),
#  ('RateMyProfessors', 82833),
#  ('GSVM', 82947),
#  ('Muhaisen', 83135),
#  ('Deliotte', 83193),
#  ('Epitec', 83201),
#  ('Lhotsampas', 83526),
#  ('panchs', 83707),
#  ('localite', 83783),
#  ('gazzetted', 83871),
#  ('Laxmikanth', 84811),
#  ('Egleson', 84846),
#  ('BJPs', 84966),
#  ('Pilikula', 85110),
#  ('Maithan', 85505),
#  ('Niser', 86165),
#  ('Dhurv', 86226),
#  ('accelerographs', 86397),
#  ('loktantra', 87587),
#  ('IGIMS', 87640),
#  ('BPTH', 87684),
#  ('Sukumara', 87916),
#  ('Guarraci', 88811),
#  ('repolling', 88889),
#  ('Conferido', 88931),
#  ('Qingtongxia', 89314),
#  ('Behrampur', 89453),
#  ('Elor', 89561),
#  ('Lengshuijiang', 89928),
#  ('Demauro', 90347),
#  ('Spokeperson', 90508),
#  ('germophobia', 90605),
#  ('Pocharam', 91658),
#  ('NCDRC', 91807),
#  ('Falnir', 91853),
#  ('JITO', 92161),
#  ('Ahemadabad', 92238),
#  ('sidedly', 92580),
#  ('Clarahan', 93273),
#  ('Modicare', 93433),
#  ('GYLC', 94350),
#  ('Mangalik', 94817),
#  ('Shivpur', 95527),
#  ('Ruichang', 96080),
#  ('RGIA', 96433),
#  ('但是', 96979),
#  ('Satyawati', 97022),
#  ('Yashaswini', 97036),
#  ('IIRM', 97257),
#  ('IHMs', 97561),
#  ('Keibul', 97590),
#  ('Lamjao', 97591),
#  ('TOELF', 97810),
#  ('Osunwa', 97934),
#  ('Springdales', 98238),
#  ('Kustanai', 98539),
#  ('Tasmac', 98738),
#  ('Neeri', 98776),
#  ('क्या', 98786),
#  ('GNOP', 99109),
#  ('Sundgaard', 99168),
#  ('Daquis', 99220),
#  ('iNautix', 99753),
#  ('Mersel', 100095),
#  ('Microdosing', 100220),
#  ('IGGMC', 100291),
#  ('DBDA', 100462),
#  ('Daringbadi', 100488),
#  ('OFSS', 100534),
#  ('Turgel', 101111),
#  ('Harmanpreet', 101208),
#  ('madressah', 101299),
#  ('Madasamy', 101372),
#  ('Banwarilal', 101394),
#  ('Amdavadis', 101539),
#  ('manjha', 101969),
#  ('Amrendra', 102012),
#  ('BITSians', 102387),
#  ('Bhubhaneshwar', 102940),
#  ('Morarjee', 103115),
#  ('Molka', 103634),
#  ('Muzzafarnagar', 103656),
#  ('Jansangh', 103727),
#  ('Zuehlsdorff', 104080),
#  ('Kuenyehia', 104092),
#  ('GSECL', 104115),
#  ('Chehebar', 104634),
#  ('Ghanti', 105098),
#  ('Jeppu', 105565),
#  ('Ophthotech', 105606),
#  ('Karumanchi', 105673),
#  ('Anandiben', 105691),
#  ('Nidey', 105776),
#  ('NITD', 105800),
#  ('Shanica', 106141),
#  ('Maulanas', 106351),
#  ('Lukanin', 106536),
#  ('Krysiuk', 106728),
#  ('bhaang', 106854),
#  ('Zimbabawe', 106855),
#  ('Bondre', 106915),
#  ('CMTU', 106977),
#  ('Hedgcoxe', 107254),
#  ('Ghitorni', 107450),
#  ('Sagoon', 107545),
#  ('Tewani', 107966),
#  ('Yobbos', 107991),
#  ('Vaculin', 108164),
#  ('BRFL', 108197),
#  ('Yeddurappa', 108372),
#  ('Alvoid', 108693),
#  ('Swagatham', 108805),
#  ('Campco', 108889),
#  ('TNIE', 108893),
#  ('Debasree', 108922),
#  ('Maheta', 109046),
#  ('Vipasha', 109233),
#  ('vakalatnama', 109351),
#  ('AJEX', 109384),
#  ('Vivimed', 109459),
#  ('Whati', 109827),
#  ('BATSMEN', 109951),
#  ('understaff', 110047),
#  ('Wellassa', 110181),
#  ('polyhouses', 110389),
#  ('Kafil', 110636),
#  ('Shalby', 110883),
#  ('Manisankar', 110911),
#  ('Amdavadi', 110934),
#  ('langars', 110967),
#  ('Basaveshwaranagar', 111049),
#  ('Toranagallu', 111361),
#  ('Globalsoft', 111554),
#  ('Tamhankar', 111793),
#  ('tribalised', 112053),
#  ('Purvankara', 112060),
#  ('AIBT', 112115),
#  ('Bhumkar', 112145),
#  ('offtaker', 112156),
#  ('Arkavathy', 112183),
#  ('Pimavanserin', 112207),
#  ('McEdwards', 112211),
#  ('Fengjun', 112532),
#  ('Shantabai', 112671),
#  ('请', 112712),
#  ('weedicide', 113174),
#  ('Kamalnath', 113200),
#  ('Benczkowski', 113291),
#  ('Fronning', 113355),
#  ('WGPA', 113413),
#  ('SKUAST', 113440),
#  ('Mankita', 113609),
#  ('Ayaa', 113764),
#  ('TYBA', 113889),
#  ('Brickenden', 114247),
#  ('answersheet', 114408),
#  ('LTWP', 114458),
#  ('Vonderschmitt', 114488),
#  ('Vanjara', 114518),
#  ('Karunandhi', 114750),
#  ('Liliyana', 114846),
#  ('Legutko', 114973),
#  ('Ngobese', 114991),
#  ('Radhabinod', 115063),
#  ('Kirorimal', 115400),
#  ('FortiASIC', 115468),
#  ('Ananthkumar', 115735),
#  ('Taonan', 116078),
#  ('VREP', 116263),
#  ('Medvedi', 116548),
#  ('Sunderbani', 116635),
#  ('nanobioscience', 116674),
#  ('underfishing', 116789),
#  ('mismanagements', 117054),
#  ('defacers', 117404),
#  ('Bypolls', 117490),
#  ('CICPA', 117682),
#  ('DHARWAD', 117759),
#  ('Korutla', 117788),
#  ('Schmedding', 117841),
#  ('Sidhbari', 117880),
#  ('Goldschmeding', 117990),
#  ('Chatunga', 118042),
#  ('CIOE', 118128),
#  ('CBAL', 118300),
#  ('Nelani', 118304),
#  ('Vanasthalipuram', 118333),
#  ('sarpanchs', 118563),
#  ('qualifieds', 118582),
#  ('Kokapet', 118650),
#  ('Janiro', 118695),
#  ('PayCommerce', 118847),
#  ('Navera', 118919),
#  ('denuclearise', 119226),
#  ('overdeveloping', 119254),
#  ('Bramell', 119622),
#  ('Janjatis', 119691),
#  ('Kemu', 119718),
#  ('conquesting', 119739),
#  ('Bakarwals', 119790),
#  ('authourities', 119799)]

# %%
missing_index = set()
for i in range(1,nb_words):
    if not embedding_count[i]:
        missing_index.add(i)

# %%
missing_words = {}
for k, v in word_index.items():
    if v in missing_index:
        missing_words[k] = v

# %%
len(missing_words)
# Out:
# 8620

# %% [raw]
# 15876

# %%
missing_words
# Out:
# {'Quorans': 1939,
#  'UCEED': 8354,
#  'BNBR': 9579,
#  'Machedo': 9601,
#  'Qoura': 11097,
#  'LNMIIT': 11984,
#  'Zerodha': 12348,
#  'Kavalireddi': 12540,
#  'Doklam': 13167,
#  'Vajiram': 13318,
#  'Unacademy': 13523,
#  'MUOET': 14021,
#  'AlShamsi': 14074,
#  'Bhakts': 14745,
#  'HackerRank': 14785,
#  'eLitmus': 15602,
#  'SRMJEE': 15894,
#  'coinbase': 16222,
#  'SGSITS': 16618,
#  'upwork': 17566,
#  'BMSCE': 17576,
#  'Binance': 17722,
#  'SRMJEEE': 17985,
#  'Zebpay': 17990,
#  'Golang': 18566,
#  'MHCET': 19298,
#  'Adhaar': 20110,
#  'PESSAT': 20299,
#  'Koinex': 20329,
#  'adhaar': 20485,
#  'demonitisation': 20511,
#  'USICT': 20823,
#  'LBSNAA': 20863,
#  'unacademy': 21260,
#  'Whst': 21455,
#  'ReactJS': 21721,
#  'Codeforces': 22331,
#  'Demonetization': 22390,
#  'Fiitjee': 22422,
#  'Trumpcare': 22461,
#  'Bittrex': 22624,
#  'Irodov': 22638,
#  'FTRE': 22672,
#  'tensorflow': 22692,
#  'Tensorflow': 22803,
#  'Simpliv': 22983,
#  'Howcan': 23015,
#  'JoSAA': 23197,
#  'NLUs': 23362,
#  'MHTCET': 23456,
#  'RLWL': 23509,
#  'IIITH': 23541,
#  'IGDTUW': 23621,
#  'apist': 24489,
#  'Xiomi': 24584,
#  'Whydo': 24604,
#  'chapterwise': 24605,
#  'undergraduation': 24638,
#  'overbrace': 24794,
#  'schizoids': 24935,
#  'IIITD': 24970,
#  'hotstar': 25120,
#  'JioFi': 25230,
#  'VSSUT': 25265,
#  'AKTU': 25273,
#  'AIATS': 25386,
#  'andMe': 25409,
#  'zebpay': 25464,
#  'twinflame': 25647,
#  'HBTU': 25679,
#  'Zenfone': 25742,
#  'Veerwal': 25774,
#  'MMMUT': 25832,
#  'nanodegree': 25886,
#  'PMAY': 26121,
#  'EXTC': 26305,
#  'Sarahah': 26636,
#  'Padmaavat': 26651,
#  'Steemit': 26803,
#  'Nanodegree': 27262,
#  'koinex': 27322,
#  'HackerEarth': 27436,
#  'TISSNET': 27510,
#  'Swiggy': 27546,
#  'don´t': 27585,
#  'Jupyter': 27650,
#  'Awdesh': 27888,
#  'mhtcet': 27924,
#  'Mbappe': 28148,
#  'sarahah': 28158,
#  'ftre': 28232,
#  'IPMAT': 28388,
#  'PayTM': 28419,
#  'cos2x': 28486,
#  'Qidian': 28528,
#  'SSCBS': 28636,
#  'LNCT': 28716,
#  'UPESEAT': 28817,
#  'XXXTentacion': 28926,
#  'Whyis': 29097,
#  'srmjee': 29148,
#  'USACO': 29193,
#  'zerodha': 29206,
#  'IFoS': 29391,
#  'AIEEA': 29400,
#  'I´m': 29533,
#  'MSQE': 29738,
#  'AILET': 29865,
#  'Dhinchak': 30051,
#  'internshala': 30165,
#  'Padmavat': 30233,
#  'HSEE': 30286,
#  'VITMEE': 30379,
#  'Oneplus': 30678,
#  'BMSIT': 30762,
#  '₹1': 30893,
#  'Plancess': 30921,
#  'Taehyung': 30924,
#  'Bitconnect': 31012,
#  'demonitization': 31020,
#  'Killmonger': 31057,
#  'UGEE': 31221,
#  'Kefla': 31317,
#  'IIHM': 31416,
#  'covfefe': 31509,
#  'MAKAUT': 31601,
#  'YourQuote': 31678,
#  'WikiTribune': 31879,
#  'NSEJS': 32077,
#  'NITians': 32124,
#  'Brexiters': 32149,
#  'PGDBF': 32178,
#  'Electroneum': 32368,
#  'Ravindrababu': 32488,
#  'opham': 32532,
#  'GSTIN': 32543,
#  'Practo': 32577,
#  'narcissit': 32935,
#  'VITEE': 32948,
#  'jiofi': 33378,
#  'HYPSM': 33412,
#  'Kilimall': 33437,
#  'AIMCAT': 33457,
#  'andme': 33479,
#  'BALLB': 33595,
#  'C6H': 33710,
#  'Brexiteers': 33775,
#  'Feku': 33842,
#  'muoet': 33872,
#  'MPSTME': 34056,
#  'Tamilans': 34070,
#  'MobiKwik': 34095,
#  'HomePod': 34233,
#  'mhcet': 34454,
#  'wumao': 34558,
#  'Poloniex': 34590,
#  'LRDI': 34625,
#  'TQWL': 34937,
#  'RCOEM': 35088,
#  'Otsutsuki': 35247,
#  'JECRC': 35391,
#  'remainers': 35434,
#  'ncerts': 35624,
#  'IMUCET': 35691,
#  'Lenskart': 35740,
#  'electroneum': 35846,
#  'class9': 35931,
#  'Minance': 36115,
#  'VESIT': 36131,
#  'BYJU': 36151,
#  'WebAssembly': 36273,
#  'sinA': 36466,
#  'Zoomcar': 36467,
#  'Bartetzko': 36546,
#  'GraphQL': 36671,
#  'cringiest': 36784,
#  'Whydoes': 36947,
#  'darkweb': 37027,
#  'IERT': 37082,
#  'Tambrahms': 37137,
#  'SPPU': 37299,
#  'gaslighted': 37363,
#  'IPUCET': 37398,
#  'PhonePe': 37408,
#  'IGST': 37436,
#  'PGDIE': 37523,
#  'Sanghis': 37691,
#  'Unocoin': 37733,
#  'DILR': 37780,
#  'freebitco': 37879,
#  'Jipmer': 37925,
#  'thicc': 37951,
#  'gaslighter': 37952,
#  'byjus': 38076,
#  'RNSIT': 38107,
#  'Remainers': 38127,
#  'Petuhov': 38136,
#  'flipcart': 38212,
#  'BASLP': 38391,
#  'NCERTs': 38521,
#  'Elitmus': 38622,
#  'boruto': 38664,
#  'mmmut': 38685,
#  'Antminer': 38753,
#  'ARKit': 39014,
#  'sklearn': 39204,
#  'A2As': 39231,
#  'FRDI': 39249,
#  'toppr': 39289,
#  'Rejuvalex': 39395,
#  'Midoriya': 39461,
#  'Trezor': 39483,
#  'Gujratis': 39541,
#  'BVCOE': 39617,
#  'NLUO': 39635,
#  'Howdoes': 39743,
#  'Demonetisation': 39761,
#  'BitConnect': 39820,
#  'machedo': 39839,
#  'GDAX': 39904,
#  'RBEI': 40037,
#  'AlphaZero': 40153,
#  'CPTSD': 40285,
#  'Microservices': 40404,
#  'Quoras': 40576,
#  'Internshala': 40672,
#  'Whichis': 40797,
#  'ShopClues': 40813,
#  'crytocurrency': 40866,
#  'jeemains': 41088,
#  'Bumrah': 41201,
#  'IIITDM': 41223,
#  'oswaal': 41497,
#  'cosecx': 41506,
#  '9A0': 41543,
#  'Haptik': 41567,
#  'Stardew': 41611,
#  'B1B2': 41624,
#  'PyTorch': 41656,
#  'Nearbuy': 41695,
#  'CIWG': 41742,
#  'testbook': 41766,
#  'jungkook': 41770,
#  'binance': 41828,
#  'FMGE': 41838,
#  'WWhat': 41878,
#  'Hashflare': 41899,
#  'Skripals': 41977,
#  'rlwl': 42020,
#  'Webnovel': 42176,
#  'doklam': 42257,
#  'SIMSREE': 42265,
#  'empowr': 42380,
#  'narcisists': 42401,
#  'byju': 42411,
#  'Philando': 42420,
#  'biromantic': 42436,
#  'WILP': 42484,
#  'Azdome': 42558,
#  'sallery': 42559,
#  'musigma': 42577,
#  'LSTMs': 42593,
#  'Antshares': 42605,
#  'cotx': 42734,
#  'thighing': 42958,
#  'BigHit': 42998,
#  'tanA': 43113,
#  'Wishfie': 43137,
#  'MnC': 43215,
#  'UberEats': 43389,
#  'lnct': 43394,
#  'Cgl': 43455,
#  'I️': 43517,
#  'PGDHRM': 43622,
#  'cosA': 43652,
#  'H2So4': 43709,
#  'Sharudenko': 43731,
#  'IGTV': 43754,
#  'Randyll': 43774,
#  'zenfone': 43824,
#  'AADHAR': 43928,
#  'vitee': 43955,
#  'Ciaz': 44000,
#  'JNUEE': 44067,
#  'aiats': 44131,
#  'XVG': 44146,
#  'polyhouse': 44222,
#  'ISBF': 44293,
#  'CUCET': 44363,
#  'bittrex': 44386,
#  'can´t': 44445,
#  'ravindrababu': 44491,
#  'Ibps': 44511,
#  '₹5': 44534,
#  'GTBIT': 44555,
#  'Altcoins': 44562,
#  'DSATM': 44692,
#  'touchbar': 44713,
#  'freecodecamp': 44796,
#  'Nidahas': 44874,
#  'Kvpy': 44875,
#  'Izuku': 44913,
#  'Tezos': 44922,
#  'locopilot': 45023,
#  'theeta': 45119,
#  'cryptocoin': 45373,
#  'Whatdo': 45382,
#  'digilocker': 45393,
#  'Pribumi': 45414,
#  'NMAMIT': 45423,
#  'angular2': 45758,
#  'GFRG': 45771,
#  'PUBDET': 45907,
#  'What´s': 45985,
#  'sapiosexual': 46000,
#  'RMLNLU': 46011,
#  'OMSCS': 46027,
#  'lbsnaa': 46131,
#  'Bathla': 46144,
#  'LeetCode': 46280,
#  'DITISS': 46377,
#  'padmavat': 46391,
#  'Yiannopolous': 46460,
#  'LPUNEST': 46461,
#  'aktu': 46470,
#  'DataCamp': 46583,
#  'Nagerkovil': 46585,
#  'NITian': 46596,
#  'Mangalapuram': 46639,
#  'Terroristan': 46664,
#  'fitjee': 46697,
#  'preboards': 46737,
#  'Aksener': 46861,
#  'JGEC': 46874,
#  'GoLang': 46876,
#  'AIACTR': 46900,
#  '5lpa': 46948,
#  'AngularJs': 47061,
#  'possesiveness': 47103,
#  'suryanamaskar': 47171,
#  'Howdid': 47217,
#  'electrovalent': 47241,
#  'cryptocurency': 47288,
#  'upvoters': 47295,
#  'PyQt5': 47320,
#  'phycopath': 47370,
#  'Juicero': 47433,
#  'demonatisation': 47488,
#  'Aayog': 47599,
#  'intenship': 47615,
#  'crytocurrencies': 47623,
#  'webnovel': 47664,
#  'madheshis': 47682,
#  'MVIT': 47844,
#  'srmjeee': 47852,
#  'Parmanu': 47854,
#  'Caulifla': 47874,
#  'JGLS': 47877,
#  'Thadomal': 47974,
#  'IITTM': 48053,
#  'AMWF': 48088,
#  'DUJAT': 48116,
#  'IITRAM': 48163,
#  'kingroot': 48187,
#  'adityanath': 48237,
#  'lenchon': 48268,
#  'Freshworks': 48281,
#  'cryptocoins': 48303,
#  '4xy': 48340,
#  'XeF6': 48482,
#  'Snapay': 48555,
#  'Trumpsters': 48649,
#  'Debotosh': 48652,
#  'Scripbox': 48674,
#  'bitconnect': 48781,
#  'etoos': 48848,
#  'bschools': 48852,
#  'oversmart': 49025,
#  'etherum': 49110,
#  'Mewani': 49114,
#  'Angular2': 49169,
#  'mastuburation': 49209,
#  'trignometric': 49230,
#  'microservice': 49283,
#  'dichlorine': 49290,
#  'cryptocurreny': 49304,
#  'Quorians': 49323,
#  'Oliveboard': 49395,
#  'Ōtsutsuki': 49398,
#  'antibrahmin': 49466,
#  'Shifuji': 49478,
#  'golgappa': 49515,
#  '1mole': 49516,
#  'delhite': 49532,
#  'orthocentre': 49573,
#  'Eastwatch': 49612,
#  'PayUMoney': 49662,
#  '2lakhs': 49770,
#  '3sin': 49788,
#  'TSPSC': 49837,
#  'Toppr': 49841,
#  'SHAREit': 49854,
#  'fuckboys': 49915,
#  'Blinkist': 49994,
#  'LoRa': 50003,
#  'Gateforum': 50008,
#  'StayBay': 50129,
#  'whatsaap': 50157,
#  'Mevani': 50185,
#  'PMKVY': 50211,
#  'Wbjee': 50231,
#  'ScoopWhoop': 50254,
#  'Xenoverse': 50342,
#  'Josaa': 50416,
#  'uppcs': 50454,
#  'powerbanks': 50475,
#  'Altcoin': 50497,
#  'SSJB': 50499,
#  'hbtu': 50573,
#  'rajyasabha': 50604,
#  'UPPCS': 50613,
#  'whatapp': 50650,
#  'Happeno': 50660,
#  'Mechnovate': 50713,
#  'filecoin': 50714,
#  'RGNUL': 50767,
#  'KGEC': 50866,
#  'mukt': 50879,
#  'narcicist': 50943,
#  'Angularjs': 50969,
#  'venturimeter': 50977,
#  'secA': 51110,
#  'FITJEE': 51127,
#  'madeeasy': 51193,
#  'Khazari': 51270,
#  'Filmora': 51275,
#  'Onecoin': 51338,
#  'INSOFE': 51384,
#  'Whatdoes': 51386,
#  'arctg': 51412,
#  'cos6x': 51421,
#  'sevmeyene': 51438,
#  'Siacoin': 51454,
#  'Xcent': 51489,
#  'Sockistan': 51559,
#  'PIBM': 51610,
#  'PlayerUnknown': 51776,
#  'Wjy': 51781,
#  'Ahch': 51789,
#  'whattsapp': 51832,
#  'iqoption': 51876,
#  '2lakh': 52002,
#  'लगाना': 52035,
#  'VueJS': 52047,
#  'Brexiting': 52109,
#  'leetcode': 52125,
#  'Tedro': 52149,
#  'SPIPA': 52170,
#  'IIPR': 52228,
#  'Airpods': 52257,
#  '8values': 52287,
#  'Rakshaks': 52293,
#  'Animoji': 52310,
#  'Arunabh': 52317,
#  'NUALS': 52361,
#  'Lpu': 52421,
#  'H1B1': 52619,
#  'Na2S2O3': 52626,
#  'Gerassimou': 52663,
#  'tutorialspoint': 52665,
#  '₹2': 52714,
#  'word2vec': 52751,
#  'Bytecoin': 52759,
#  'gravational': 52809,
#  'S7E7': 52834,
#  'Eindiawholesale': 52840,
#  'YYGS': 52850,
#  'Calltend': 52872,
#  'Trumpists': 52926,
#  'onecoin': 53010,
#  'UiPath': 53045,
#  'C8H': 53063,
#  'Belmod': 53064,
#  'IUBH': 53099,
#  '1lac': 53103,
#  'cph4': 53110,
#  'kovind': 53162,
#  'Codechef': 53202,
#  'Ngannou': 53207,
#  '2theta': 53237,
#  'Phinks': 53283,
#  'Oumuamua': 53297,
#  'Cabba': 53298,
#  'XeF4': 53343,
#  'prilims': 53357,
#  'HashFlare': 53365,
#  'Etoos': 53431,
#  'Hakaishin': 53460,
#  'cryptoassets': 53547,
#  'SegWit2x': 53551,
#  'UpGrad': 53611,
#  'Whuch': 53704,
#  'makaut': 53725,
#  'mutarotation': 53833,
#  'TFWS': 53856,
#  'Pixelbook': 53879,
#  'Tracxn': 53896,
#  'kgmc': 53901,
#  'gangrapes': 53946,
#  'Decofest': 53957,
#  'HNLU': 53970,
#  'BSTAT': 53983,
#  'narcassist': 53985,
#  'airpods': 54027,
#  'Whyare': 54031,
#  'Jiofi': 54043,
#  'pharmD': 54179,
#  'whtsapp': 54309,
#  'AIMCATs': 54343,
#  'balayam': 54421,
#  'Tnpsc': 54464,
#  'freecharge': 54474,
#  'Subnautica': 54500,
#  'seq2seq': 54583,
#  'statergy': 54593,
#  'Tenseigan': 54737,
#  'JioPhone': 54777,
#  'lhmc': 54802,
#  'Tamoghna': 54808,
#  'UpWork': 54953,
#  'laliga': 54959,
#  'MITID': 54970,
#  'superscore': 55085,
#  'ANTHE': 55160,
#  'Gitlab': 55164,
#  'techmahindra': 55213,
#  'disapparate': 55222,
#  'duplet': 55224,
#  'Dentacoin': 55241,
#  'C5H': 55271,
#  'BNYS': 55316,
#  'jeemain': 55330,
#  'overcaring': 55390,
#  'kgmu': 55483,
#  'Accolite': 55504,
#  'patreon': 55616,
#  'snapchats': 55678,
#  'Flipcart': 55778,
#  'Altacoin': 55816,
#  'nitroaniline': 55841,
#  'DCRUST': 55854,
#  'usict': 55871,
#  'Hapnes': 55880,
#  '÷2': 55903,
#  'PayTm': 55954,
#  'spaCy': 55997,
#  'Divyansh': 55998,
#  'redme': 56095,
#  'TUEE': 56117,
#  'demonitised': 56128,
#  'vaxxers': 56143,
#  'BStat': 56171,
#  'kalpit': 56174,
#  'k2cr2o7': 56256,
#  'Oberlo': 56265,
#  'Icetratt': 56297,
#  'Pahul': 56391,
#  'prepation': 56400,
#  'IOFS': 56404,
#  'x₁': 56504,
#  'awdhesh': 56505,
#  'autoencoders': 56528,
#  'cyrptocurrency': 56573,
#  'H2so4': 56616,
#  'Dogsee': 56617,
#  'Howis': 56635,
#  'Whivh': 56669,
#  'sin3x': 56697,
#  'methanoic': 56703,
#  'satoshis': 56708,
#  'HYPS': 56716,
#  'tanB': 56790,
#  'rakshaks': 56804,
#  'jiophone': 56829,
#  'Paramhansha': 56874,
#  'dictorship': 56884,
#  'PGPEM': 56919,
#  'DigiBank': 57036,
#  'IIsc': 57045,
#  'Antardasha': 57048,
#  'CaC2': 57074,
#  'kubernetes': 57103,
#  'Auliq': 57120,
#  'ciswomen': 57144,
#  'Whqt': 57151,
#  'NetLogon': 57162,
#  'Damodardas': 57163,
#  'IQOS': 57181,
#  'Nanoray': 57198,
#  'MAHCET': 57326,
#  'Ichange': 57374,
#  'ammonical': 57444,
#  'Chhillar': 57473,
#  'cotA': 57500,
#  'Whatkind': 57509,
#  'Tejashwi': 57517,
#  'cryto': 57558,
#  'stateboard': 57579,
#  'GFTI': 57601,
#  'Bschools': 57635,
#  'padmaavat': 57643,
#  '4sin': 57794,
#  'fmovies': 57812,
#  'whatsap': 57843,
#  'btcxindia': 57856,
#  'Novanto': 57936,
#  'LLb': 57972,
#  'litecoins': 57993,
#  'Geostorm': 58040,
#  'boglin': 58046,
#  'QTUM': 58080,
#  'nodemcu': 58083,
#  'I´ve': 58102,
#  'PGWP': 58106,
#  'Guluzar': 58112,
#  'Tufenk': 58113,
#  'Bakchod': 58120,
#  'PGEE': 58197,
#  'smoothning': 58242,
#  'ConsDeva': 58244,
#  'Kuchibhotla': 58255,
#  'siacoin': 58263,
#  'meosis': 58275,
#  'IITH': 58350,
#  'BBr3': 58357,
#  'elctron': 58372,
#  'unhack': 58400,
#  'permitivity': 58437,
#  'syntaxial': 58484,
#  'Whatwas': 58490,
#  'Gigun': 58560,
#  'Kamalan': 58561,
#  'moLotus': 58573,
#  'ARCore': 58579,
#  'MESRA': 58586,
#  'Instagress': 58588,
#  'Wherecan': 58625,
#  'Gazwa': 58632,
#  'GSTR1': 58698,
#  'Nawaj': 58711,
#  'Qspiders': 58713,
#  'preprations': 58732,
#  'Gazef': 58749,
#  'IIMUN': 58773,
#  'Ncert': 58818,
#  'ReLEx': 58848,
#  'Almyrantis': 58876,
#  'BYJUs': 58918,
#  'SIMSR': 58939,
#  'OINP': 58942,
#  'fullstack': 58949,
#  'subjectwise': 59002,
#  'GNDEC': 59023,
#  'payzapp': 59063,
#  'demonetizing': 59132,
#  'cos3x': 59147,
#  'kissanime': 59150,
#  'Kotoamatsukami': 59173,
#  'fadnavis': 59263,
#  'QUORA': 59276,
#  'Upes': 59336,
#  'Thalaivas': 59433,
#  'cosB': 59490,
#  'IARE': 59499,
#  'undergrade': 59517,
#  'codejam': 59520,
#  '5LPA': 59523,
#  'XXXtentacion': 59538,
#  'niftem': 59540,
#  'oliveboard': 59645,
#  'becone': 59649,
#  'NITW': 59668,
#  'TMISAT': 59679,
#  'Pashupatastra': 59759,
#  'AKGEC': 59796,
#  'proschool': 59818,
#  'muchhal': 59879,
#  'janeu': 59900,
#  'kavalireddi': 59902,
#  'indominus': 59982,
#  'Whatvis': 59993,
#  'vidmate': 60018,
#  'hardfork': 60020,
#  'G5S': 60121,
#  'Vajubhai': 60134,
#  'tissnet': 60250,
#  'Geometrifying': 60327,
#  'remoaners': 60340,
#  'WMAF': 60417,
#  'Holdo': 60434,
#  'PGDBDA': 60440,
#  'DoMS': 60447,
#  'bromoethane': 60468,
#  'homescience': 60474,
#  '0mL': 60513,
#  'p5bqAKixgYA': 60521,
#  'autoliker': 60525,
#  'feminazism': 60528,
#  'draqonians': 60552,
#  'Auvela': 60637,
#  'Namjoon': 60692,
#  'dhinchak': 60696,
#  'ranklist': 60757,
#  'AllinCall': 60795,
#  'nestaway': 60833,
#  'collges': 60860,
#  'Ntorq': 60905,
#  'ryzen': 60959,
#  'pshycology': 60967,
#  'subjecs': 60999,
#  'CPH4': 61043,
#  'xcos': 61063,
#  'iphone7': 61110,
#  'nofap': 61174,
#  'cscx': 61231,
#  'criptocurrency': 61243,
#  'bftech': 61265,
#  'Wgat': 61311,
#  'unocoin': 61326,
#  'weatern': 61448,
#  'cofficient': 61453,
#  'pwBPD': 61469,
#  'Quroa': 61479,
#  'vaxxer': 61516,
#  'Jedha': 61527,
#  'semiovale': 61528,
#  'Jewism': 61551,
#  'WGSHA': 61562,
#  'Databricks': 61612,
#  'Zcash': 61704,
#  'civilservice': 61730,
#  'MBRDI': 61731,
#  'Pachamuthu': 61814,
#  'Lunyr': 61817,
#  'iodometric': 61833,
#  'electrones': 61842,
#  'Katalon': 61854,
#  'engeeniring': 61872,
#  'Segwit2x': 61905,
#  'Mphill': 61908,
#  'igst': 61936,
#  'Tapzo': 62020,
#  'SRFP': 62066,
#  'plazzo': 62094,
#  'bumrah': 62102,
#  'Cavaciuti': 62111,
#  'LBSIM': 62113,
#  'igrua': 62119,
#  'mesosomes': 62133,
#  'cocubes': 62147,
#  'lacture': 62197,
#  'LNCTS': 62218,
#  'musterbation': 62280,
#  'NIACL': 62308,
#  'reneet': 62362,
#  'blockhain': 62440,
#  'unadded': 62451,
#  'didn´t': 62471,
#  'Eu4': 62495,
#  'MSRUAS': 62510,
#  'Katappa': 62537,
#  'nearbuy': 62542,
#  'hashgraph': 62606,
#  'UDAN': 62612,
#  'Byjus': 62641,
#  'ipucet': 62696,
#  'Ryokshin': 62743,
#  'communicantes': 62790,
#  'LiteCoin': 62862,
#  'OfferUp': 62882,
#  'fulform': 62884,
#  'root3': 62909,
#  'ReLU': 62916,
#  'Whatbis': 62955,
#  'Indoraptor': 62979,
#  'mottephobia': 62981,
#  'thiests': 62996,
#  'segwit2x': 63018,
#  'pillani': 63020,
#  'scikit': 63042,
#  'BTCI': 63045,
#  'BPIT': 63071,
#  'aromantics': 63116,
#  'kasganj': 63173,
#  'dropshiping': 63199,
#  'RecyclerView': 63287,
#  'tetrabromomethane': 63301,
#  'PGDISEM': 63303,
#  'iihm': 63320,
#  '2tan': 63410,
#  'reconducted': 63418,
#  'bakths': 63435,
#  'Mobikwik': 63439,
#  'vistara': 63465,
#  'mastubrate': 63498,
#  'Qarib': 63511,
#  'moeslim': 63519,
#  'jiren': 63570,
#  'NordVPN': 63583,
#  'Statesians': 63645,
#  'linient': 63660,
#  'evion': 63764,
#  'psycopathy': 63838,
#  'CSe': 63855,
#  'NITTE': 63894,
#  'H0w': 63931,
#  'foodpanda': 63934,
#  'Shingrix': 63964,
#  'Danaerys': 64001,
#  'workex': 64047,
#  'Fornite': 64065,
#  'SonarQube': 64067,
#  '∆G': 64084,
#  'Eurocentrics': 64085,
#  'unexempted': 64114,
#  'yesbank': 64160,
#  'Deepmind': 64169,
#  'IITIANS': 64192,
#  'Eroupian': 64197,
#  'myetherwallet': 64211,
#  'MERN': 64220,
#  'JUET': 64244,
#  'Uraraka': 64268,
#  'Woxsen': 64312,
#  'Tejasvita': 64315,
#  'x₂': 64318,
#  'sinB': 64331,
#  'minance': 64338,
#  'Viserion': 64382,
#  'IITJAM': 64386,
#  'PIWAT': 64392,
#  'edWisor': 64425,
#  'Wjat': 64450,
#  'mānuka': 64464,
#  '5cr': 64481,
#  'Tilki': 64514,
#  'FreeCodeCamp': 64523,
#  'Kurud': 64527,
#  'selfstudy': 64528,
#  'Momoshiki': 64530,
#  'dπ': 64620,
#  'pπ': 64621,
#  'microneedling': 64622,
#  'AcSIR': 64634,
#  'PGDAC': 64642,
#  'sinC': 64652,
#  'diffentiate': 64717,
#  'PPDT': 64733,
#  'BVBCET': 64806,
#  'UPCPAT': 64818,
#  'narccisist': 64825,
#  'enggineering': 64843,
#  'Neduvasal': 64855,
#  'FYERS': 64914,
#  'cishet': 64946,
#  'tybcom': 65017,
#  'IOAA': 65021,
#  'sickular': 65066,
#  'K2Cr2O7': 65116,
#  'Naharis': 65192,
#  'contentmart': 65195,
#  'TSICET': 65198,
#  'propan': 65213,
#  'speedforce': 65217,
#  'Etherum': 65250,
#  'Rohinga': 65291,
#  'Printful': 65321,
#  'Odissa': 65374,
#  'narcissts': 65407,
#  'namakharam': 65429,
#  'deplation': 65566,
#  'Fullstack': 65571,
#  'DSIM': 65580,
#  'NDEB': 65593,
#  'Asifas': 65607,
#  'Dimash': 65609,
#  'narcist': 65642,
#  'vssut': 65647,
#  '3marks': 65648,
#  'Whatwill': 65677,
#  'topicwise': 65708,
#  'Earny': 65711,
#  'WorldQuant': 65718,
#  'Duspatalin': 65845,
#  'Quotev': 65846,
#  'Ksin': 65850,
#  'cos4x': 65873,
#  'Storj': 65914,
#  'immigate': 65958,
#  'BlockChain': 65959,
#  'swellness': 65979,
#  'PGDIM': 65983,
#  'synergids': 66018,
#  'Jaats': 66026,
#  'gallaxies': 66034,
#  'Lnt': 66039,
#  'UIIC': 66044,
#  'coading': 66049,
#  'ReactJs': 66062,
#  'vivegam': 66089,
#  'Yolt': 66114,
#  'eKYC': 66125,
#  'Ozhukarai': 66126,
#  'Mereya': 66135,
#  'USABO': 66136,
#  'ionocraft': 66183,
#  'Deplorables': 66270,
#  'Nojoto': 66283,
#  'socialpath': 66309,
#  'Vibetrace': 66333,
#  'metaphysicists': 66374,
#  'thappar': 66385,
#  'Mechantronics': 66386,
#  'theDifference': 66398,
#  'Codius': 66416,
#  'ProductHunt': 66434,
#  'teespring': 66439,
#  'landran': 66466,
#  'Veselnitskaya': 66478,
#  'twinflames': 66479,
#  'cyptocurrencies': 66534,
#  'ComedK': 66542,
#  'DigiByte': 66589,
#  'Dadmi': 66599,
#  'masterbution': 66600,
#  'CDPI': 66615,
#  'loniness': 66640,
#  'acedamy': 66656,
#  'MCODS': 66691,
#  'Watsapp': 66726,
#  'Kreatryx': 66737,
#  'sppu': 66760,
#  'aurdino': 66764,
#  'Nicmar': 66779,
#  'ipmat': 66827,
#  'resofast': 66873,
#  'BLACKIS': 66899,
#  'Mattermark': 66923,
#  'jecrc': 66940,
#  'Kushners': 66971,
#  'root7': 66975,
#  'BetterHelp': 66991,
#  'Xiami': 67105,
#  'Sharetribe': 67111,
#  'Stya': 67121,
#  'Rumsshi': 67128,
#  'Mayanti': 67157,
#  'xender': 67163,
#  'demcoratic': 67194,
#  '\u202aWhat': 67195,
#  'bhallaladeva': 67206,
#  'westbengal': 67208,
#  'Howshould': 67236,
#  'fentynal': 67239,
#  'dropers': 67246,
#  'EtherParty': 67248,
#  'faminism': 67267,
#  'FighterZ': 67282,
#  'QMAS': 67286,
#  'Harrapa': 67287,
#  'kaand': 67334,
#  'softmore': 67351,
#  'Whh': 67412,
#  'aghoris': 67429,
#  'northindians': 67435,
#  'khatna': 67477,
#  'deepweb': 67478,
#  'diffetence': 67480,
#  'Foap': 67484,
#  'dz2': 67500,
#  'neurodivergent': 67506,
#  'gomed': 67524,
#  'parajumbles': 67529,
#  'Stronoff': 67530,
#  'PrOPEL': 67534,
#  'disvantages': 67552,
#  'urbanpro': 67555,
#  'BeCl2': 67656,
#  'Whatdid': 67661,
#  'REDMI': 67699,
#  'IITGN': 67710,
#  'Mirakee': 67736,
#  'kharmas': 67783,
#  'पड़ना': 67831,
#  'cantrol': 67853,
#  'nanodegrees': 67888,
#  '1RK': 67922,
#  'voltmetre': 67940,
#  'LLRM': 67963,
#  'janmabhumi': 67974,
#  ...}

# %% [raw]
# missing_words['sjws']

# %%
high_freq = set()
for i in range(1,nb_words):
    if embedding_count[i] > 10:
        high_freq.add(i)

# %%
high_freq_words = {}
for k, v in word_index.items():
    if v in high_freq:
        high_freq_words[k] = v

# %%
len(high_freq_words)
# Out:
# 0

# %%
high_freq_words
# Out:
# {}

# %% [markdown]
# # Changing ordering of embeddings and creating matrix

# %%
# LIST OF ALL EMBEDDINGS USED
embedding_list = [PATH+'embeddings/glove.840B.300d/glove.840B.300d.txt', PATH+'embeddings/paragram_300_sl999/paragram_300_sl999.txt', PATH+'embeddings/wiki-news-300d-1M/wiki-news-300d-1M.vec']

# MEAN AND STD VALUES FOR EMBEDDINGS
emb_mean_dict = {'paragram_300_sl999':-0.005324783269315958,
            'wiki-news-300d-1M':-0.0033469984773546457,
            'glove.840B.300d':-0.005838498938828707,
            'GoogleNews-vectors-negative300':-0.0051106834}

emb_std_dict = {'paragram_300_sl999':0.4934646189212799,
            'wiki-news-300d-1M':0.10985549539327621,
            'glove.840B.300d':0.4878219664096832,
            'GoogleNews-vectors-negative300':0.18445626}

global_mean = np.mean([i for i in emb_mean_dict.values()])
global_std = np.mean([i for i in emb_std_dict.values()])
global_embedding = np.random.normal(global_mean, global_std, (nb_words, embed_size))
embedding_count = np.zeros((nb_words,1))

# %%
# %%time
word_count_embedding = [0, 0 ,0]
for k in range(len(embedding_list)):
    embedding_name = embedding_list[k].split('/')[3]
    for o in open(embedding_list[k], encoding="utf8", errors='ignore'):
        word, vec = o.split(' ', 1)
        if word not in word_index:
            continue
        i = word_index[word]
        if i >= nb_words or embedding_count[i] > 0:
            continue
        embedding_vector = np.asarray(vec.split(' '), dtype='float32')[:embed_size]
        if len(embedding_vector) == embed_size:
            global_embedding[i] = embedding_vector
            embedding_count[i] += 1
            word_count_embedding[k] += 1
    print(embedding_name, '\t', word_count_embedding[k])
    del embedding_vector
    gc.collect()
# Out:
# glove.840B.300d 	 109017
# paragram_300_sl999 	 1164
# wiki-news-300d-1M 	 883
# CPU times: user 19 s, sys: 2.66 s, total: 21.6 s
# Wall time: 21.5 s

# %% [raw]
# wiki-news-300d-1M 	 104067
# glove.840B.300d 	 5889
# paragram_300_sl999 	 1108
# CPU times: user 16.5 s, sys: 2.45 s, total: 18.9 s
# Wall time: 18.8 s

# %%
pd.Series(embedding_count.flatten()).value_counts().sort_index()/len(embedding_count) * 100
# Out:
# 0.0     7.446667
# 1.0    92.553333
# dtype: float64

# %% [raw]
# # No to lower
# 0.0     7.446667
# 1.0     3.472500
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64
#
# 0.0     13.775833
# 1.0      1.074167
# 2.0      3.471667
# 3.0     10.931667
# 4.0      9.928333
# 5.0     18.512500
# 6.0     23.145000
# 7.0     13.899167
# 8.0      2.923333
# 9.0      1.560833
# 10.0     0.395000
# 11.0     0.191667
# 12.0     0.071667
# 13.0     0.050833
# 14.0     0.026667
# 15.0     0.013333
# 16.0     0.009167
# 17.0     0.009167
# 18.0     0.005000
# 19.0     0.001667
# 21.0     0.002500
# 22.0     0.000833
# dtype: float64
#
# # New spellings
# 3.0    61.1275
# 2.0    15.1950
# 0.0    14.5275
# 1.0     9.1500
#
# # Old spellings
# 3.0    61.1225
# 2.0    15.1925
# 0.0    14.5350
# 1.0     9.1500
# dtype: float64

# %%
word2vecpath = PATH + 'embeddings/GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'

# %%
unique_words = set()

# %%
# %%time
with utils.smart_open(word2vecpath) as fin:
    header = utils.to_unicode(fin.readline(), encoding='utf8')
    vocab_size, vector_size = (int(x) for x in header.split())
    binary_len = np.dtype(np.float32).itemsize * vector_size
    for _ in tqdm(range(vocab_size)):
        word = []
        while True:
            ch = fin.read(1)
            if ch == b' ':
                break
            if ch == b'':
                raise EOFError("unexpected end of input")
            if ch != b'\n':
                word.append(ch)
        word = utils.to_unicode(b''.join(word), encoding='utf8', errors='strict')
        weights = np.fromstring(fin.read(binary_len), dtype=np.float32).astype(np.float32)
        if word not in word_index:
            continue
        i = word_index[word]
        if i >= nb_words or embedding_count[i] > 0:
            continue
        unique_words.add((word,i))
        global_embedding[i] = weights
        embedding_count[i] += 1
# Out:
#   0%|          | 0/3000000 [00:00<?, ?it/s]/home/apg/all_dl/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   app.launch_new_instance()
# 100%|██████████| 3000000/3000000 [00:27<00:00, 109972.39it/s]
# CPU times: user 26.5 s, sys: 1.1 s, total: 27.6 s
# Wall time: 27.3 s

# %%
pd.Series(embedding_count.flatten()).value_counts().sort_index()/len(embedding_count) * 100
# Out:
# 0.0     7.184167
# 1.0    92.815833
# dtype: float64

# %% [raw]
# # No to lower
# 0.0     7.184167
# 1.0     3.735000
# 2.0    42.301667
# 3.0    46.779167
# dtype: float64
#
# 0.0     13.230833
# 1.0      1.619167
# 2.0      3.471667
# 3.0     10.931667
# 4.0      9.928333
# 5.0     18.512500
# 6.0     23.145000
# 7.0     13.899167
# 8.0      2.923333
# 9.0      1.560833
# 10.0     0.395000
# 11.0     0.191667
# 12.0     0.071667
# 13.0     0.050833
# 14.0     0.026667
# 15.0     0.013333
# 16.0     0.009167
# 17.0     0.009167
# 18.0     0.005000
# 19.0     0.001667
# 21.0     0.002500
# 22.0     0.000833
# dtype: float64
#
# 3.0    61.127500
# 2.0    15.195000
# 0.0    14.460833
# 1.0     9.216667
# dtype: float64
#
# # word2vec with old spellings
# 3.0    61.122500
# 2.0    15.192500
# 0.0    14.468333
# 1.0     9.216667
# dtype: float64

# %%
len(unique_words)
# Out:
# 315

# %%
sorted(unique_words, key=lambda tup: tup[1])
# Out:
# [('bhakts', 12849),
#  ('NICMAR', 13079),
#  ('Awdhesh', 15039),
#  ('Skripal', 16686),
#  ('Alshamsi', 17181),
#  ('BIPC', 17547),
#  ('IISERs', 20109),
#  ('Byju', 21234),
#  ('UPSE', 22209),
#  ('Kalpit', 23119),
#  ('EFLU', 25644),
#  ('Kovind', 26999),
#  ('Strzok', 27353),
#  ('Kattankulathur', 27857),
#  ('Kainerugaba', 28464),
#  ('Warmbier', 28831),
#  ('PESU', 29713),
#  ('RGIPT', 30995),
#  ('DSCE', 32526),
#  ('LHMC', 33946),
#  ('KGMU', 34097),
#  ('Gurmehar', 37441),
#  ('PRMO', 38584),
#  ('NIFTEM', 39386),
#  ('IPHO', 40070),
#  ('Jozwik', 42042),
#  ('Bregoli', 43445),
#  ('1crore', 45068),
#  ('Delloite', 46168),
#  ('Rupay', 47777),
#  ('Kejariwal', 48961),
#  ('Kahoot', 49659),
#  ('PIVX', 51176),
#  ('GTPL', 51465),
#  ('multibaggers', 51954),
#  ('JN0', 52726),
#  ('SJMSOM', 52989),
#  ('Mersal', 53257),
#  ('MNLU', 53935),
#  ('SGTB', 54938),
#  ('PSIT', 55481),
#  ('IGRUA', 56196),
#  ('Bijwasan', 56394),
#  ('Kolkey', 56666),
#  ('Awadesh', 57230),
#  ('Hampankatta', 57999),
#  ('Dwarikesh', 58225),
#  ('Netralaya', 59341),
#  ('OPTCL', 59489),
#  ('Meghmani', 59850),
#  ('subinspector', 61056),
#  ('Cihon', 61103),
#  ('FIEM', 61624),
#  ('TenX', 62637),
#  ('Landran', 62933),
#  ('MVSR', 63142),
#  ('NLIU', 63209),
#  ('Kulbushan', 63283),
#  ('SRFTI', 64077),
#  ('retainership', 65010),
#  ('STCG', 65428),
#  ('SMVDU', 65557),
#  ('Acads', 66002),
#  ('Appium', 66035),
#  ('Myeshia', 66735),
#  ('Doncic', 66802),
#  ('Regenesys', 66818),
#  ('secondyear', 66973),
#  ('Duranto', 67528),
#  ('Mueth', 67653),
#  ('Dundigal', 68486),
#  ('PMEGP', 68591),
#  ('Swaroopa', 68621),
#  ('Glucon', 69641),
#  ('Koparkhairane', 70766),
#  ('Dawki', 70865),
#  ('Contris', 70888),
#  ('Jeou', 71649),
#  ('Bakliwal', 71984),
#  ('Kolhan', 72823),
#  ('Shiradi', 72939),
#  ('Anudeep', 73060),
#  ('SILCHAR', 73438),
#  ('Arbind', 73633),
#  ('Peeya', 73851),
#  ('PGPEX', 74730),
#  ('nutraloaf', 74775),
#  ('Raazi', 75284),
#  ('Ayog', 75638),
#  ('Yedyurappa', 76260),
#  ('Pandeshwar', 76676),
#  ('DISEC', 76763),
#  ('VGSOM', 76777),
#  ('Pahadis', 76852),
#  ('QLED', 76942),
#  ('answersheets', 77101),
#  ('Janambhoomi', 77495),
#  ('CoEP', 78086),
#  ('Tawhidi', 78410),
#  ('Mudipu', 79046),
#  ('Gboard', 79047),
#  ('CENP', 79488),
#  ('Samundra', 79767),
#  ('NDTL', 79893),
#  ('relagation', 80156),
#  ('Shoaibi', 80346),
#  ('hosteller', 80356),
#  ('DDIT', 81303),
#  ('Mehtani', 81328),
#  ('KRIBHCO', 81342),
#  ('IMTMA', 81736),
#  ('Gwader', 82071),
#  ('NITR', 82118),
#  ('JNMC', 82307),
#  ('Gossert', 82570),
#  ('RateMyProfessors', 82833),
#  ('GSVM', 82947),
#  ('Muhaisen', 83135),
#  ('Deliotte', 83193),
#  ('Epitec', 83201),
#  ('Lhotsampas', 83526),
#  ('panchs', 83707),
#  ('localite', 83783),
#  ('gazzetted', 83871),
#  ('Laxmikanth', 84811),
#  ('Egleson', 84846),
#  ('BJPs', 84966),
#  ('Pilikula', 85110),
#  ('Maithan', 85505),
#  ('Niser', 86165),
#  ('Dhurv', 86226),
#  ('accelerographs', 86397),
#  ('loktantra', 87587),
#  ('IGIMS', 87640),
#  ('BPTH', 87684),
#  ('Sukumara', 87916),
#  ('Guarraci', 88811),
#  ('repolling', 88889),
#  ('Conferido', 88931),
#  ('Qingtongxia', 89314),
#  ('Behrampur', 89453),
#  ('Elor', 89561),
#  ('Lengshuijiang', 89928),
#  ('Demauro', 90347),
#  ('Spokeperson', 90508),
#  ('germophobia', 90605),
#  ('Pocharam', 91658),
#  ('NCDRC', 91807),
#  ('Falnir', 91853),
#  ('JITO', 92161),
#  ('Ahemadabad', 92238),
#  ('sidedly', 92580),
#  ('Clarahan', 93273),
#  ('Modicare', 93433),
#  ('GYLC', 94350),
#  ('Mangalik', 94817),
#  ('Shivpur', 95527),
#  ('Ruichang', 96080),
#  ('RGIA', 96433),
#  ('但是', 96979),
#  ('Satyawati', 97022),
#  ('Yashaswini', 97036),
#  ('IIRM', 97257),
#  ('IHMs', 97561),
#  ('Keibul', 97590),
#  ('Lamjao', 97591),
#  ('TOELF', 97810),
#  ('Osunwa', 97934),
#  ('Springdales', 98238),
#  ('Kustanai', 98539),
#  ('Tasmac', 98738),
#  ('Neeri', 98776),
#  ('क्या', 98786),
#  ('GNOP', 99109),
#  ('Sundgaard', 99168),
#  ('Daquis', 99220),
#  ('iNautix', 99753),
#  ('Mersel', 100095),
#  ('Microdosing', 100220),
#  ('IGGMC', 100291),
#  ('DBDA', 100462),
#  ('Daringbadi', 100488),
#  ('OFSS', 100534),
#  ('Turgel', 101111),
#  ('Harmanpreet', 101208),
#  ('madressah', 101299),
#  ('Madasamy', 101372),
#  ('Banwarilal', 101394),
#  ('Amdavadis', 101539),
#  ('manjha', 101969),
#  ('Amrendra', 102012),
#  ('BITSians', 102387),
#  ('Bhubhaneshwar', 102940),
#  ('Morarjee', 103115),
#  ('Molka', 103634),
#  ('Muzzafarnagar', 103656),
#  ('Jansangh', 103727),
#  ('Zuehlsdorff', 104080),
#  ('Kuenyehia', 104092),
#  ('GSECL', 104115),
#  ('Chehebar', 104634),
#  ('Ghanti', 105098),
#  ('Jeppu', 105565),
#  ('Ophthotech', 105606),
#  ('Karumanchi', 105673),
#  ('Anandiben', 105691),
#  ('Nidey', 105776),
#  ('NITD', 105800),
#  ('Shanica', 106141),
#  ('Maulanas', 106351),
#  ('Lukanin', 106536),
#  ('Krysiuk', 106728),
#  ('bhaang', 106854),
#  ('Zimbabawe', 106855),
#  ('Bondre', 106915),
#  ('CMTU', 106977),
#  ('Hedgcoxe', 107254),
#  ('Ghitorni', 107450),
#  ('Sagoon', 107545),
#  ('Tewani', 107966),
#  ('Yobbos', 107991),
#  ('Vaculin', 108164),
#  ('BRFL', 108197),
#  ('Yeddurappa', 108372),
#  ('Alvoid', 108693),
#  ('Swagatham', 108805),
#  ('Campco', 108889),
#  ('TNIE', 108893),
#  ('Debasree', 108922),
#  ('Maheta', 109046),
#  ('Vipasha', 109233),
#  ('vakalatnama', 109351),
#  ('AJEX', 109384),
#  ('Vivimed', 109459),
#  ('Whati', 109827),
#  ('BATSMEN', 109951),
#  ('understaff', 110047),
#  ('Wellassa', 110181),
#  ('polyhouses', 110389),
#  ('Kafil', 110636),
#  ('Shalby', 110883),
#  ('Manisankar', 110911),
#  ('Amdavadi', 110934),
#  ('langars', 110967),
#  ('Basaveshwaranagar', 111049),
#  ('Toranagallu', 111361),
#  ('Globalsoft', 111554),
#  ('Tamhankar', 111793),
#  ('tribalised', 112053),
#  ('Purvankara', 112060),
#  ('AIBT', 112115),
#  ('Bhumkar', 112145),
#  ('offtaker', 112156),
#  ('Arkavathy', 112183),
#  ('Pimavanserin', 112207),
#  ('McEdwards', 112211),
#  ('Fengjun', 112532),
#  ('Shantabai', 112671),
#  ('请', 112712),
#  ('weedicide', 113174),
#  ('Kamalnath', 113200),
#  ('Benczkowski', 113291),
#  ('Fronning', 113355),
#  ('WGPA', 113413),
#  ('SKUAST', 113440),
#  ('Mankita', 113609),
#  ('Ayaa', 113764),
#  ('TYBA', 113889),
#  ('Brickenden', 114247),
#  ('answersheet', 114408),
#  ('LTWP', 114458),
#  ('Vonderschmitt', 114488),
#  ('Vanjara', 114518),
#  ('Karunandhi', 114750),
#  ('Liliyana', 114846),
#  ('Legutko', 114973),
#  ('Ngobese', 114991),
#  ('Radhabinod', 115063),
#  ('Kirorimal', 115400),
#  ('FortiASIC', 115468),
#  ('Ananthkumar', 115735),
#  ('Taonan', 116078),
#  ('VREP', 116263),
#  ('Medvedi', 116548),
#  ('Sunderbani', 116635),
#  ('nanobioscience', 116674),
#  ('underfishing', 116789),
#  ('mismanagements', 117054),
#  ('defacers', 117404),
#  ('Bypolls', 117490),
#  ('CICPA', 117682),
#  ('DHARWAD', 117759),
#  ('Korutla', 117788),
#  ('Schmedding', 117841),
#  ('Sidhbari', 117880),
#  ('Goldschmeding', 117990),
#  ('Chatunga', 118042),
#  ('CIOE', 118128),
#  ('CBAL', 118300),
#  ('Nelani', 118304),
#  ('Vanasthalipuram', 118333),
#  ('sarpanchs', 118563),
#  ('qualifieds', 118582),
#  ('Kokapet', 118650),
#  ('Janiro', 118695),
#  ('PayCommerce', 118847),
#  ('Navera', 118919),
#  ('denuclearise', 119226),
#  ('overdeveloping', 119254),
#  ('Bramell', 119622),
#  ('Janjatis', 119691),
#  ('Kemu', 119718),
#  ('conquesting', 119739),
#  ('Bakarwals', 119790),
#  ('authourities', 119799)]

# %%
missing_index = set()
for i in range(1,nb_words):
    if not embedding_count[i]:
        missing_index.add(i)

# %%
missing_words = {}
for k, v in word_index.items():
    if v in missing_index:
        missing_words[k] = v

# %%
len(missing_words)
# Out:
# 8620

# %% [raw]
# 15876

# %%
missing_words
# Out:
# {'Quorans': 1939,
#  'UCEED': 8354,
#  'BNBR': 9579,
#  'Machedo': 9601,
#  'Qoura': 11097,
#  'LNMIIT': 11984,
#  'Zerodha': 12348,
#  'Kavalireddi': 12540,
#  'Doklam': 13167,
#  'Vajiram': 13318,
#  'Unacademy': 13523,
#  'MUOET': 14021,
#  'AlShamsi': 14074,
#  'Bhakts': 14745,
#  'HackerRank': 14785,
#  'eLitmus': 15602,
#  'SRMJEE': 15894,
#  'coinbase': 16222,
#  'SGSITS': 16618,
#  'upwork': 17566,
#  'BMSCE': 17576,
#  'Binance': 17722,
#  'SRMJEEE': 17985,
#  'Zebpay': 17990,
#  'Golang': 18566,
#  'MHCET': 19298,
#  'Adhaar': 20110,
#  'PESSAT': 20299,
#  'Koinex': 20329,
#  'adhaar': 20485,
#  'demonitisation': 20511,
#  'USICT': 20823,
#  'LBSNAA': 20863,
#  'unacademy': 21260,
#  'Whst': 21455,
#  'ReactJS': 21721,
#  'Codeforces': 22331,
#  'Demonetization': 22390,
#  'Fiitjee': 22422,
#  'Trumpcare': 22461,
#  'Bittrex': 22624,
#  'Irodov': 22638,
#  'FTRE': 22672,
#  'tensorflow': 22692,
#  'Tensorflow': 22803,
#  'Simpliv': 22983,
#  'Howcan': 23015,
#  'JoSAA': 23197,
#  'NLUs': 23362,
#  'MHTCET': 23456,
#  'RLWL': 23509,
#  'IIITH': 23541,
#  'IGDTUW': 23621,
#  'apist': 24489,
#  'Xiomi': 24584,
#  'Whydo': 24604,
#  'chapterwise': 24605,
#  'undergraduation': 24638,
#  'overbrace': 24794,
#  'schizoids': 24935,
#  'IIITD': 24970,
#  'hotstar': 25120,
#  'JioFi': 25230,
#  'VSSUT': 25265,
#  'AKTU': 25273,
#  'AIATS': 25386,
#  'andMe': 25409,
#  'zebpay': 25464,
#  'twinflame': 25647,
#  'HBTU': 25679,
#  'Zenfone': 25742,
#  'Veerwal': 25774,
#  'MMMUT': 25832,
#  'nanodegree': 25886,
#  'PMAY': 26121,
#  'EXTC': 26305,
#  'Sarahah': 26636,
#  'Padmaavat': 26651,
#  'Steemit': 26803,
#  'Nanodegree': 27262,
#  'koinex': 27322,
#  'HackerEarth': 27436,
#  'TISSNET': 27510,
#  'Swiggy': 27546,
#  'don´t': 27585,
#  'Jupyter': 27650,
#  'Awdesh': 27888,
#  'mhtcet': 27924,
#  'Mbappe': 28148,
#  'sarahah': 28158,
#  'ftre': 28232,
#  'IPMAT': 28388,
#  'PayTM': 28419,
#  'cos2x': 28486,
#  'Qidian': 28528,
#  'SSCBS': 28636,
#  'LNCT': 28716,
#  'UPESEAT': 28817,
#  'XXXTentacion': 28926,
#  'Whyis': 29097,
#  'srmjee': 29148,
#  'USACO': 29193,
#  'zerodha': 29206,
#  'IFoS': 29391,
#  'AIEEA': 29400,
#  'I´m': 29533,
#  'MSQE': 29738,
#  'AILET': 29865,
#  'Dhinchak': 30051,
#  'internshala': 30165,
#  'Padmavat': 30233,
#  'HSEE': 30286,
#  'VITMEE': 30379,
#  'Oneplus': 30678,
#  'BMSIT': 30762,
#  '₹1': 30893,
#  'Plancess': 30921,
#  'Taehyung': 30924,
#  'Bitconnect': 31012,
#  'demonitization': 31020,
#  'Killmonger': 31057,
#  'UGEE': 31221,
#  'Kefla': 31317,
#  'IIHM': 31416,
#  'covfefe': 31509,
#  'MAKAUT': 31601,
#  'YourQuote': 31678,
#  'WikiTribune': 31879,
#  'NSEJS': 32077,
#  'NITians': 32124,
#  'Brexiters': 32149,
#  'PGDBF': 32178,
#  'Electroneum': 32368,
#  'Ravindrababu': 32488,
#  'opham': 32532,
#  'GSTIN': 32543,
#  'Practo': 32577,
#  'narcissit': 32935,
#  'VITEE': 32948,
#  'jiofi': 33378,
#  'HYPSM': 33412,
#  'Kilimall': 33437,
#  'AIMCAT': 33457,
#  'andme': 33479,
#  'BALLB': 33595,
#  'C6H': 33710,
#  'Brexiteers': 33775,
#  'Feku': 33842,
#  'muoet': 33872,
#  'MPSTME': 34056,
#  'Tamilans': 34070,
#  'MobiKwik': 34095,
#  'HomePod': 34233,
#  'mhcet': 34454,
#  'wumao': 34558,
#  'Poloniex': 34590,
#  'LRDI': 34625,
#  'TQWL': 34937,
#  'RCOEM': 35088,
#  'Otsutsuki': 35247,
#  'JECRC': 35391,
#  'remainers': 35434,
#  'ncerts': 35624,
#  'IMUCET': 35691,
#  'Lenskart': 35740,
#  'electroneum': 35846,
#  'class9': 35931,
#  'Minance': 36115,
#  'VESIT': 36131,
#  'BYJU': 36151,
#  'WebAssembly': 36273,
#  'sinA': 36466,
#  'Zoomcar': 36467,
#  'Bartetzko': 36546,
#  'GraphQL': 36671,
#  'cringiest': 36784,
#  'Whydoes': 36947,
#  'darkweb': 37027,
#  'IERT': 37082,
#  'Tambrahms': 37137,
#  'SPPU': 37299,
#  'gaslighted': 37363,
#  'IPUCET': 37398,
#  'PhonePe': 37408,
#  'IGST': 37436,
#  'PGDIE': 37523,
#  'Sanghis': 37691,
#  'Unocoin': 37733,
#  'DILR': 37780,
#  'freebitco': 37879,
#  'Jipmer': 37925,
#  'thicc': 37951,
#  'gaslighter': 37952,
#  'byjus': 38076,
#  'RNSIT': 38107,
#  'Remainers': 38127,
#  'Petuhov': 38136,
#  'flipcart': 38212,
#  'BASLP': 38391,
#  'NCERTs': 38521,
#  'Elitmus': 38622,
#  'boruto': 38664,
#  'mmmut': 38685,
#  'Antminer': 38753,
#  'ARKit': 39014,
#  'sklearn': 39204,
#  'A2As': 39231,
#  'FRDI': 39249,
#  'toppr': 39289,
#  'Rejuvalex': 39395,
#  'Midoriya': 39461,
#  'Trezor': 39483,
#  'Gujratis': 39541,
#  'BVCOE': 39617,
#  'NLUO': 39635,
#  'Howdoes': 39743,
#  'Demonetisation': 39761,
#  'BitConnect': 39820,
#  'machedo': 39839,
#  'GDAX': 39904,
#  'RBEI': 40037,
#  'AlphaZero': 40153,
#  'CPTSD': 40285,
#  'Microservices': 40404,
#  'Quoras': 40576,
#  'Internshala': 40672,
#  'Whichis': 40797,
#  'ShopClues': 40813,
#  'crytocurrency': 40866,
#  'jeemains': 41088,
#  'Bumrah': 41201,
#  'IIITDM': 41223,
#  'oswaal': 41497,
#  'cosecx': 41506,
#  '9A0': 41543,
#  'Haptik': 41567,
#  'Stardew': 41611,
#  'B1B2': 41624,
#  'PyTorch': 41656,
#  'Nearbuy': 41695,
#  'CIWG': 41742,
#  'testbook': 41766,
#  'jungkook': 41770,
#  'binance': 41828,
#  'FMGE': 41838,
#  'WWhat': 41878,
#  'Hashflare': 41899,
#  'Skripals': 41977,
#  'rlwl': 42020,
#  'Webnovel': 42176,
#  'doklam': 42257,
#  'SIMSREE': 42265,
#  'empowr': 42380,
#  'narcisists': 42401,
#  'byju': 42411,
#  'Philando': 42420,
#  'biromantic': 42436,
#  'WILP': 42484,
#  'Azdome': 42558,
#  'sallery': 42559,
#  'musigma': 42577,
#  'LSTMs': 42593,
#  'Antshares': 42605,
#  'cotx': 42734,
#  'thighing': 42958,
#  'BigHit': 42998,
#  'tanA': 43113,
#  'Wishfie': 43137,
#  'MnC': 43215,
#  'UberEats': 43389,
#  'lnct': 43394,
#  'Cgl': 43455,
#  'I️': 43517,
#  'PGDHRM': 43622,
#  'cosA': 43652,
#  'H2So4': 43709,
#  'Sharudenko': 43731,
#  'IGTV': 43754,
#  'Randyll': 43774,
#  'zenfone': 43824,
#  'AADHAR': 43928,
#  'vitee': 43955,
#  'Ciaz': 44000,
#  'JNUEE': 44067,
#  'aiats': 44131,
#  'XVG': 44146,
#  'polyhouse': 44222,
#  'ISBF': 44293,
#  'CUCET': 44363,
#  'bittrex': 44386,
#  'can´t': 44445,
#  'ravindrababu': 44491,
#  'Ibps': 44511,
#  '₹5': 44534,
#  'GTBIT': 44555,
#  'Altcoins': 44562,
#  'DSATM': 44692,
#  'touchbar': 44713,
#  'freecodecamp': 44796,
#  'Nidahas': 44874,
#  'Kvpy': 44875,
#  'Izuku': 44913,
#  'Tezos': 44922,
#  'locopilot': 45023,
#  'theeta': 45119,
#  'cryptocoin': 45373,
#  'Whatdo': 45382,
#  'digilocker': 45393,
#  'Pribumi': 45414,
#  'NMAMIT': 45423,
#  'angular2': 45758,
#  'GFRG': 45771,
#  'PUBDET': 45907,
#  'What´s': 45985,
#  'sapiosexual': 46000,
#  'RMLNLU': 46011,
#  'OMSCS': 46027,
#  'lbsnaa': 46131,
#  'Bathla': 46144,
#  'LeetCode': 46280,
#  'DITISS': 46377,
#  'padmavat': 46391,
#  'Yiannopolous': 46460,
#  'LPUNEST': 46461,
#  'aktu': 46470,
#  'DataCamp': 46583,
#  'Nagerkovil': 46585,
#  'NITian': 46596,
#  'Mangalapuram': 46639,
#  'Terroristan': 46664,
#  'fitjee': 46697,
#  'preboards': 46737,
#  'Aksener': 46861,
#  'JGEC': 46874,
#  'GoLang': 46876,
#  'AIACTR': 46900,
#  '5lpa': 46948,
#  'AngularJs': 47061,
#  'possesiveness': 47103,
#  'suryanamaskar': 47171,
#  'Howdid': 47217,
#  'electrovalent': 47241,
#  'cryptocurency': 47288,
#  'upvoters': 47295,
#  'PyQt5': 47320,
#  'phycopath': 47370,
#  'Juicero': 47433,
#  'demonatisation': 47488,
#  'Aayog': 47599,
#  'intenship': 47615,
#  'crytocurrencies': 47623,
#  'webnovel': 47664,
#  'madheshis': 47682,
#  'MVIT': 47844,
#  'srmjeee': 47852,
#  'Parmanu': 47854,
#  'Caulifla': 47874,
#  'JGLS': 47877,
#  'Thadomal': 47974,
#  'IITTM': 48053,
#  'AMWF': 48088,
#  'DUJAT': 48116,
#  'IITRAM': 48163,
#  'kingroot': 48187,
#  'adityanath': 48237,
#  'lenchon': 48268,
#  'Freshworks': 48281,
#  'cryptocoins': 48303,
#  '4xy': 48340,
#  'XeF6': 48482,
#  'Snapay': 48555,
#  'Trumpsters': 48649,
#  'Debotosh': 48652,
#  'Scripbox': 48674,
#  'bitconnect': 48781,
#  'etoos': 48848,
#  'bschools': 48852,
#  'oversmart': 49025,
#  'etherum': 49110,
#  'Mewani': 49114,
#  'Angular2': 49169,
#  'mastuburation': 49209,
#  'trignometric': 49230,
#  'microservice': 49283,
#  'dichlorine': 49290,
#  'cryptocurreny': 49304,
#  'Quorians': 49323,
#  'Oliveboard': 49395,
#  'Ōtsutsuki': 49398,
#  'antibrahmin': 49466,
#  'Shifuji': 49478,
#  'golgappa': 49515,
#  '1mole': 49516,
#  'delhite': 49532,
#  'orthocentre': 49573,
#  'Eastwatch': 49612,
#  'PayUMoney': 49662,
#  '2lakhs': 49770,
#  '3sin': 49788,
#  'TSPSC': 49837,
#  'Toppr': 49841,
#  'SHAREit': 49854,
#  'fuckboys': 49915,
#  'Blinkist': 49994,
#  'LoRa': 50003,
#  'Gateforum': 50008,
#  'StayBay': 50129,
#  'whatsaap': 50157,
#  'Mevani': 50185,
#  'PMKVY': 50211,
#  'Wbjee': 50231,
#  'ScoopWhoop': 50254,
#  'Xenoverse': 50342,
#  'Josaa': 50416,
#  'uppcs': 50454,
#  'powerbanks': 50475,
#  'Altcoin': 50497,
#  'SSJB': 50499,
#  'hbtu': 50573,
#  'rajyasabha': 50604,
#  'UPPCS': 50613,
#  'whatapp': 50650,
#  'Happeno': 50660,
#  'Mechnovate': 50713,
#  'filecoin': 50714,
#  'RGNUL': 50767,
#  'KGEC': 50866,
#  'mukt': 50879,
#  'narcicist': 50943,
#  'Angularjs': 50969,
#  'venturimeter': 50977,
#  'secA': 51110,
#  'FITJEE': 51127,
#  'madeeasy': 51193,
#  'Khazari': 51270,
#  'Filmora': 51275,
#  'Onecoin': 51338,
#  'INSOFE': 51384,
#  'Whatdoes': 51386,
#  'arctg': 51412,
#  'cos6x': 51421,
#  'sevmeyene': 51438,
#  'Siacoin': 51454,
#  'Xcent': 51489,
#  'Sockistan': 51559,
#  'PIBM': 51610,
#  'PlayerUnknown': 51776,
#  'Wjy': 51781,
#  'Ahch': 51789,
#  'whattsapp': 51832,
#  'iqoption': 51876,
#  '2lakh': 52002,
#  'लगाना': 52035,
#  'VueJS': 52047,
#  'Brexiting': 52109,
#  'leetcode': 52125,
#  'Tedro': 52149,
#  'SPIPA': 52170,
#  'IIPR': 52228,
#  'Airpods': 52257,
#  '8values': 52287,
#  'Rakshaks': 52293,
#  'Animoji': 52310,
#  'Arunabh': 52317,
#  'NUALS': 52361,
#  'Lpu': 52421,
#  'H1B1': 52619,
#  'Na2S2O3': 52626,
#  'Gerassimou': 52663,
#  'tutorialspoint': 52665,
#  '₹2': 52714,
#  'word2vec': 52751,
#  'Bytecoin': 52759,
#  'gravational': 52809,
#  'S7E7': 52834,
#  'Eindiawholesale': 52840,
#  'YYGS': 52850,
#  'Calltend': 52872,
#  'Trumpists': 52926,
#  'onecoin': 53010,
#  'UiPath': 53045,
#  'C8H': 53063,
#  'Belmod': 53064,
#  'IUBH': 53099,
#  '1lac': 53103,
#  'cph4': 53110,
#  'kovind': 53162,
#  'Codechef': 53202,
#  'Ngannou': 53207,
#  '2theta': 53237,
#  'Phinks': 53283,
#  'Oumuamua': 53297,
#  'Cabba': 53298,
#  'XeF4': 53343,
#  'prilims': 53357,
#  'HashFlare': 53365,
#  'Etoos': 53431,
#  'Hakaishin': 53460,
#  'cryptoassets': 53547,
#  'SegWit2x': 53551,
#  'UpGrad': 53611,
#  'Whuch': 53704,
#  'makaut': 53725,
#  'mutarotation': 53833,
#  'TFWS': 53856,
#  'Pixelbook': 53879,
#  'Tracxn': 53896,
#  'kgmc': 53901,
#  'gangrapes': 53946,
#  'Decofest': 53957,
#  'HNLU': 53970,
#  'BSTAT': 53983,
#  'narcassist': 53985,
#  'airpods': 54027,
#  'Whyare': 54031,
#  'Jiofi': 54043,
#  'pharmD': 54179,
#  'whtsapp': 54309,
#  'AIMCATs': 54343,
#  'balayam': 54421,
#  'Tnpsc': 54464,
#  'freecharge': 54474,
#  'Subnautica': 54500,
#  'seq2seq': 54583,
#  'statergy': 54593,
#  'Tenseigan': 54737,
#  'JioPhone': 54777,
#  'lhmc': 54802,
#  'Tamoghna': 54808,
#  'UpWork': 54953,
#  'laliga': 54959,
#  'MITID': 54970,
#  'superscore': 55085,
#  'ANTHE': 55160,
#  'Gitlab': 55164,
#  'techmahindra': 55213,
#  'disapparate': 55222,
#  'duplet': 55224,
#  'Dentacoin': 55241,
#  'C5H': 55271,
#  'BNYS': 55316,
#  'jeemain': 55330,
#  'overcaring': 55390,
#  'kgmu': 55483,
#  'Accolite': 55504,
#  'patreon': 55616,
#  'snapchats': 55678,
#  'Flipcart': 55778,
#  'Altacoin': 55816,
#  'nitroaniline': 55841,
#  'DCRUST': 55854,
#  'usict': 55871,
#  'Hapnes': 55880,
#  '÷2': 55903,
#  'PayTm': 55954,
#  'spaCy': 55997,
#  'Divyansh': 55998,
#  'redme': 56095,
#  'TUEE': 56117,
#  'demonitised': 56128,
#  'vaxxers': 56143,
#  'BStat': 56171,
#  'kalpit': 56174,
#  'k2cr2o7': 56256,
#  'Oberlo': 56265,
#  'Icetratt': 56297,
#  'Pahul': 56391,
#  'prepation': 56400,
#  'IOFS': 56404,
#  'x₁': 56504,
#  'awdhesh': 56505,
#  'autoencoders': 56528,
#  'cyrptocurrency': 56573,
#  'H2so4': 56616,
#  'Dogsee': 56617,
#  'Howis': 56635,
#  'Whivh': 56669,
#  'sin3x': 56697,
#  'methanoic': 56703,
#  'satoshis': 56708,
#  'HYPS': 56716,
#  'tanB': 56790,
#  'rakshaks': 56804,
#  'jiophone': 56829,
#  'Paramhansha': 56874,
#  'dictorship': 56884,
#  'PGPEM': 56919,
#  'DigiBank': 57036,
#  'IIsc': 57045,
#  'Antardasha': 57048,
#  'CaC2': 57074,
#  'kubernetes': 57103,
#  'Auliq': 57120,
#  'ciswomen': 57144,
#  'Whqt': 57151,
#  'NetLogon': 57162,
#  'Damodardas': 57163,
#  'IQOS': 57181,
#  'Nanoray': 57198,
#  'MAHCET': 57326,
#  'Ichange': 57374,
#  'ammonical': 57444,
#  'Chhillar': 57473,
#  'cotA': 57500,
#  'Whatkind': 57509,
#  'Tejashwi': 57517,
#  'cryto': 57558,
#  'stateboard': 57579,
#  'GFTI': 57601,
#  'Bschools': 57635,
#  'padmaavat': 57643,
#  '4sin': 57794,
#  'fmovies': 57812,
#  'whatsap': 57843,
#  'btcxindia': 57856,
#  'Novanto': 57936,
#  'LLb': 57972,
#  'litecoins': 57993,
#  'Geostorm': 58040,
#  'boglin': 58046,
#  'QTUM': 58080,
#  'nodemcu': 58083,
#  'I´ve': 58102,
#  'PGWP': 58106,
#  'Guluzar': 58112,
#  'Tufenk': 58113,
#  'Bakchod': 58120,
#  'PGEE': 58197,
#  'smoothning': 58242,
#  'ConsDeva': 58244,
#  'Kuchibhotla': 58255,
#  'siacoin': 58263,
#  'meosis': 58275,
#  'IITH': 58350,
#  'BBr3': 58357,
#  'elctron': 58372,
#  'unhack': 58400,
#  'permitivity': 58437,
#  'syntaxial': 58484,
#  'Whatwas': 58490,
#  'Gigun': 58560,
#  'Kamalan': 58561,
#  'moLotus': 58573,
#  'ARCore': 58579,
#  'MESRA': 58586,
#  'Instagress': 58588,
#  'Wherecan': 58625,
#  'Gazwa': 58632,
#  'GSTR1': 58698,
#  'Nawaj': 58711,
#  'Qspiders': 58713,
#  'preprations': 58732,
#  'Gazef': 58749,
#  'IIMUN': 58773,
#  'Ncert': 58818,
#  'ReLEx': 58848,
#  'Almyrantis': 58876,
#  'BYJUs': 58918,
#  'SIMSR': 58939,
#  'OINP': 58942,
#  'fullstack': 58949,
#  'subjectwise': 59002,
#  'GNDEC': 59023,
#  'payzapp': 59063,
#  'demonetizing': 59132,
#  'cos3x': 59147,
#  'kissanime': 59150,
#  'Kotoamatsukami': 59173,
#  'fadnavis': 59263,
#  'QUORA': 59276,
#  'Upes': 59336,
#  'Thalaivas': 59433,
#  'cosB': 59490,
#  'IARE': 59499,
#  'undergrade': 59517,
#  'codejam': 59520,
#  '5LPA': 59523,
#  'XXXtentacion': 59538,
#  'niftem': 59540,
#  'oliveboard': 59645,
#  'becone': 59649,
#  'NITW': 59668,
#  'TMISAT': 59679,
#  'Pashupatastra': 59759,
#  'AKGEC': 59796,
#  'proschool': 59818,
#  'muchhal': 59879,
#  'janeu': 59900,
#  'kavalireddi': 59902,
#  'indominus': 59982,
#  'Whatvis': 59993,
#  'vidmate': 60018,
#  'hardfork': 60020,
#  'G5S': 60121,
#  'Vajubhai': 60134,
#  'tissnet': 60250,
#  'Geometrifying': 60327,
#  'remoaners': 60340,
#  'WMAF': 60417,
#  'Holdo': 60434,
#  'PGDBDA': 60440,
#  'DoMS': 60447,
#  'bromoethane': 60468,
#  'homescience': 60474,
#  '0mL': 60513,
#  'p5bqAKixgYA': 60521,
#  'autoliker': 60525,
#  'feminazism': 60528,
#  'draqonians': 60552,
#  'Auvela': 60637,
#  'Namjoon': 60692,
#  'dhinchak': 60696,
#  'ranklist': 60757,
#  'AllinCall': 60795,
#  'nestaway': 60833,
#  'collges': 60860,
#  'Ntorq': 60905,
#  'ryzen': 60959,
#  'pshycology': 60967,
#  'subjecs': 60999,
#  'CPH4': 61043,
#  'xcos': 61063,
#  'iphone7': 61110,
#  'nofap': 61174,
#  'cscx': 61231,
#  'criptocurrency': 61243,
#  'bftech': 61265,
#  'Wgat': 61311,
#  'unocoin': 61326,
#  'weatern': 61448,
#  'cofficient': 61453,
#  'pwBPD': 61469,
#  'Quroa': 61479,
#  'vaxxer': 61516,
#  'Jedha': 61527,
#  'semiovale': 61528,
#  'Jewism': 61551,
#  'WGSHA': 61562,
#  'Databricks': 61612,
#  'Zcash': 61704,
#  'civilservice': 61730,
#  'MBRDI': 61731,
#  'Pachamuthu': 61814,
#  'Lunyr': 61817,
#  'iodometric': 61833,
#  'electrones': 61842,
#  'Katalon': 61854,
#  'engeeniring': 61872,
#  'Segwit2x': 61905,
#  'Mphill': 61908,
#  'igst': 61936,
#  'Tapzo': 62020,
#  'SRFP': 62066,
#  'plazzo': 62094,
#  'bumrah': 62102,
#  'Cavaciuti': 62111,
#  'LBSIM': 62113,
#  'igrua': 62119,
#  'mesosomes': 62133,
#  'cocubes': 62147,
#  'lacture': 62197,
#  'LNCTS': 62218,
#  'musterbation': 62280,
#  'NIACL': 62308,
#  'reneet': 62362,
#  'blockhain': 62440,
#  'unadded': 62451,
#  'didn´t': 62471,
#  'Eu4': 62495,
#  'MSRUAS': 62510,
#  'Katappa': 62537,
#  'nearbuy': 62542,
#  'hashgraph': 62606,
#  'UDAN': 62612,
#  'Byjus': 62641,
#  'ipucet': 62696,
#  'Ryokshin': 62743,
#  'communicantes': 62790,
#  'LiteCoin': 62862,
#  'OfferUp': 62882,
#  'fulform': 62884,
#  'root3': 62909,
#  'ReLU': 62916,
#  'Whatbis': 62955,
#  'Indoraptor': 62979,
#  'mottephobia': 62981,
#  'thiests': 62996,
#  'segwit2x': 63018,
#  'pillani': 63020,
#  'scikit': 63042,
#  'BTCI': 63045,
#  'BPIT': 63071,
#  'aromantics': 63116,
#  'kasganj': 63173,
#  'dropshiping': 63199,
#  'RecyclerView': 63287,
#  'tetrabromomethane': 63301,
#  'PGDISEM': 63303,
#  'iihm': 63320,
#  '2tan': 63410,
#  'reconducted': 63418,
#  'bakths': 63435,
#  'Mobikwik': 63439,
#  'vistara': 63465,
#  'mastubrate': 63498,
#  'Qarib': 63511,
#  'moeslim': 63519,
#  'jiren': 63570,
#  'NordVPN': 63583,
#  'Statesians': 63645,
#  'linient': 63660,
#  'evion': 63764,
#  'psycopathy': 63838,
#  'CSe': 63855,
#  'NITTE': 63894,
#  'H0w': 63931,
#  'foodpanda': 63934,
#  'Shingrix': 63964,
#  'Danaerys': 64001,
#  'workex': 64047,
#  'Fornite': 64065,
#  'SonarQube': 64067,
#  '∆G': 64084,
#  'Eurocentrics': 64085,
#  'unexempted': 64114,
#  'yesbank': 64160,
#  'Deepmind': 64169,
#  'IITIANS': 64192,
#  'Eroupian': 64197,
#  'myetherwallet': 64211,
#  'MERN': 64220,
#  'JUET': 64244,
#  'Uraraka': 64268,
#  'Woxsen': 64312,
#  'Tejasvita': 64315,
#  'x₂': 64318,
#  'sinB': 64331,
#  'minance': 64338,
#  'Viserion': 64382,
#  'IITJAM': 64386,
#  'PIWAT': 64392,
#  'edWisor': 64425,
#  'Wjat': 64450,
#  'mānuka': 64464,
#  '5cr': 64481,
#  'Tilki': 64514,
#  'FreeCodeCamp': 64523,
#  'Kurud': 64527,
#  'selfstudy': 64528,
#  'Momoshiki': 64530,
#  'dπ': 64620,
#  'pπ': 64621,
#  'microneedling': 64622,
#  'AcSIR': 64634,
#  'PGDAC': 64642,
#  'sinC': 64652,
#  'diffentiate': 64717,
#  'PPDT': 64733,
#  'BVBCET': 64806,
#  'UPCPAT': 64818,
#  'narccisist': 64825,
#  'enggineering': 64843,
#  'Neduvasal': 64855,
#  'FYERS': 64914,
#  'cishet': 64946,
#  'tybcom': 65017,
#  'IOAA': 65021,
#  'sickular': 65066,
#  'K2Cr2O7': 65116,
#  'Naharis': 65192,
#  'contentmart': 65195,
#  'TSICET': 65198,
#  'propan': 65213,
#  'speedforce': 65217,
#  'Etherum': 65250,
#  'Rohinga': 65291,
#  'Printful': 65321,
#  'Odissa': 65374,
#  'narcissts': 65407,
#  'namakharam': 65429,
#  'deplation': 65566,
#  'Fullstack': 65571,
#  'DSIM': 65580,
#  'NDEB': 65593,
#  'Asifas': 65607,
#  'Dimash': 65609,
#  'narcist': 65642,
#  'vssut': 65647,
#  '3marks': 65648,
#  'Whatwill': 65677,
#  'topicwise': 65708,
#  'Earny': 65711,
#  'WorldQuant': 65718,
#  'Duspatalin': 65845,
#  'Quotev': 65846,
#  'Ksin': 65850,
#  'cos4x': 65873,
#  'Storj': 65914,
#  'immigate': 65958,
#  'BlockChain': 65959,
#  'swellness': 65979,
#  'PGDIM': 65983,
#  'synergids': 66018,
#  'Jaats': 66026,
#  'gallaxies': 66034,
#  'Lnt': 66039,
#  'UIIC': 66044,
#  'coading': 66049,
#  'ReactJs': 66062,
#  'vivegam': 66089,
#  'Yolt': 66114,
#  'eKYC': 66125,
#  'Ozhukarai': 66126,
#  'Mereya': 66135,
#  'USABO': 66136,
#  'ionocraft': 66183,
#  'Deplorables': 66270,
#  'Nojoto': 66283,
#  'socialpath': 66309,
#  'Vibetrace': 66333,
#  'metaphysicists': 66374,
#  'thappar': 66385,
#  'Mechantronics': 66386,
#  'theDifference': 66398,
#  'Codius': 66416,
#  'ProductHunt': 66434,
#  'teespring': 66439,
#  'landran': 66466,
#  'Veselnitskaya': 66478,
#  'twinflames': 66479,
#  'cyptocurrencies': 66534,
#  'ComedK': 66542,
#  'DigiByte': 66589,
#  'Dadmi': 66599,
#  'masterbution': 66600,
#  'CDPI': 66615,
#  'loniness': 66640,
#  'acedamy': 66656,
#  'MCODS': 66691,
#  'Watsapp': 66726,
#  'Kreatryx': 66737,
#  'sppu': 66760,
#  'aurdino': 66764,
#  'Nicmar': 66779,
#  'ipmat': 66827,
#  'resofast': 66873,
#  'BLACKIS': 66899,
#  'Mattermark': 66923,
#  'jecrc': 66940,
#  'Kushners': 66971,
#  'root7': 66975,
#  'BetterHelp': 66991,
#  'Xiami': 67105,
#  'Sharetribe': 67111,
#  'Stya': 67121,
#  'Rumsshi': 67128,
#  'Mayanti': 67157,
#  'xender': 67163,
#  'demcoratic': 67194,
#  '\u202aWhat': 67195,
#  'bhallaladeva': 67206,
#  'westbengal': 67208,
#  'Howshould': 67236,
#  'fentynal': 67239,
#  'dropers': 67246,
#  'EtherParty': 67248,
#  'faminism': 67267,
#  'FighterZ': 67282,
#  'QMAS': 67286,
#  'Harrapa': 67287,
#  'kaand': 67334,
#  'softmore': 67351,
#  'Whh': 67412,
#  'aghoris': 67429,
#  'northindians': 67435,
#  'khatna': 67477,
#  'deepweb': 67478,
#  'diffetence': 67480,
#  'Foap': 67484,
#  'dz2': 67500,
#  'neurodivergent': 67506,
#  'gomed': 67524,
#  'parajumbles': 67529,
#  'Stronoff': 67530,
#  'PrOPEL': 67534,
#  'disvantages': 67552,
#  'urbanpro': 67555,
#  'BeCl2': 67656,
#  'Whatdid': 67661,
#  'REDMI': 67699,
#  'IITGN': 67710,
#  'Mirakee': 67736,
#  'kharmas': 67783,
#  'पड़ना': 67831,
#  'cantrol': 67853,
#  'nanodegrees': 67888,
#  '1RK': 67922,
#  'voltmetre': 67940,
#  'LLRM': 67963,
#  'janmabhumi': 67974,
#  ...}

# %% [raw]
# missing_words['sjws']

# %%
high_freq = set()
for i in range(1,nb_words):
    if embedding_count[i] > 10:
        high_freq.add(i)

# %%
high_freq_words = {}
for k, v in word_index.items():
    if v in high_freq:
        high_freq_words[k] = v

# %%
len(high_freq_words)
# Out:
# 0

# %%
high_freq_words
# Out:
# {}
